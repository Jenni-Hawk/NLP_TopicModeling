# %% [markdown]
# ### LDA Probabilistic Modeling - LDA uses Gensim
# - Uses gensim simple pre-processing for tokenization

# %%
import pandas as pd
import nltk
from nltk.tokenize import sent_tokenize, word_tokenize, RegexpTokenizer
from nltk.util import ngrams
nltk.download('stopwords')
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import TruncatedSVD
import re

import gensim
from gensim import corpora, models, similarities, matutils
from gensim.models.phrases import Phrases, ENGLISH_CONNECTOR_WORDS
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# spacy for lemmatization
import spacy
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/jennihawk/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
import pyLDAvis
import pyLDAvis.gensim_models  # don't skip this
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#got tweets at 1:15 Pacific Time 10/14/22
tweets = pd.read_csv('/Users/jennihawk/Documents/Data Science/NLP_Unsupervised Learning/Project_NLP/TweetBatch3.csv')
tweets
# Out:
#                                                     text  \
# 0      @ReallyAmerican1 #Roevember and\n#ForThePeople...
# 1      RT @sandibachom: IS THIS THING ON???!!This is ...
# 2      RT @sandibachom: IS THIS THING ON???!!This is ...
# 3      RT @tleehumphrey: Today is the beginning of th...
# 4      RT @AdamKinzinger: Mitch McConnell.\nKevin McC...
# ...                                                  ...
# 34988  RT @Adrian_Fontes: The January 6th committee j...
# 34989  #January6thCommitteeHearings and everyone runn...
# 34990  RT @sandibachom: IS THIS THING ON???!!This is ...
# 34991  So they are gonna subpoena Trump I am guessing...
# 34992  RT @mariashriver: This is a historic day. @Rep...
#
#                                                  cleaned
# 0       roevember and forthepeople and votebluein2022...
# 1      rt is this thing on this is pathetic acting se...
# 2      rt is this thing on this is pathetic acting se...
# 3      rt today is the beginning of the inquiry into ...
# 4      rt mitch mcconnell kevin mccarthy they both kn...
# ...                                                  ...
# 34988  rt fontes the january 6th committee just concl...
# 34989   january6thcommitteehearings and everyone runn...
# 34990  rt is this thing on this is pathetic acting se...
# 34991  so they are gonna subpoena trump am guessing t...
# 34992  rt this is historic day words were somber rega...
#
# [34993 rows x 2 columns]

# %% [markdown]
# ### Stop Words

# %%
stop_words = stopwords.words('english')
# extend to customize list of stopwords
stop_words.extend(['rt', 'january', 'january6thcommitteehearings', 'ja'])

# %% [markdown]
# ### Create list of initially cleaned tweets
# - in this section you could also set up regex variables for further cleaning. data = regex code

# %%
data = list(tweets.cleaned)

# %% [markdown]
# ### Gensim tokenization via simple_preprocess( )
# - https://www.machinelearningplus.com/nlp/topic-modeling-gensim-python/#9createbigramandtrigrammodels

# %%
# convert to list because gensim created a generator type object and need to tell it it's a list. 
def sent_to_words(sentences):
    for sentence in sentences:
        yield(gensim.utils.simple_preprocess(str(sentence), deacc=True))  # deacc=True removes punctuations

data_words = list(sent_to_words(data))

#print(data_words)

# %%
print(type(data_words))
# Out:
# <class 'list'>

# %%
print(data_words[1])
# Out:
# ['rt', 'is', 'this', 'thing', 'on', 'this', 'is', 'pathetic', 'acting', 'sec', 'of', 'defense', 'chris', 'miller', 'was', 'the', 'only', 'person', 'who', 'can', 'deploy', 'the', 'national']

# %% [markdown]
# ### Phrases Model Arguments
# - Radi's code example https://radimrehurek.com/gensim/models/phrases.html
# - first arg takes a sequence of lists of tokens
# - min counts = minimum number of times word combination needs to be seen to be considered bigram
# - threshold = Gensim detects a bigram if a scoring function for two words exceeds a threshold - big topic - see scoring
# https://datascience.stackexchange.com/questions/25524/how-does-phrases-in-gensim-work
# - connector_words = connector_words (set of str, optional) Set of words that may be included within a phrase, without affecting its scoring. No phrase can start nor end with a connector word; a phrase may contain any number of connector words in the middle.
# - connector_words=phrases.ENGLISH_CONNECTOR_WORDS This will cause phrases to include common English articles, prepositions and conjuctions, such as bank_of_america or eye_of_the_beholder.

# %% [markdown]
# #### Build Bigram Model

# %%
# Create training corpus. Must be a sequence of sentences (e.g. an iterable or a generator).
bigram_mod = Phrases(data_words, min_count=1, threshold=1, connector_words=ENGLISH_CONNECTOR_WORDS)
# Out:
# 2022-10-25 16:50:22,085 : INFO : collecting all words and their counts
# 2022-10-25 16:50:22,086 : INFO : PROGRESS: at sentence #0, processed 0 words and 0 word types
# 2022-10-25 16:50:22,289 : INFO : PROGRESS: at sentence #10000, processed 190666 words and 25460 word types
# 2022-10-25 16:50:22,492 : INFO : PROGRESS: at sentence #20000, processed 379448 words and 40019 word types
# 2022-10-25 16:50:22,696 : INFO : PROGRESS: at sentence #30000, processed 571741 words and 51604 word types
# 2022-10-25 16:50:22,799 : INFO : collected 55276 token types (unigram + bigrams) from a corpus of 666324 words and 34993 sentences
# 2022-10-25 16:50:22,800 : INFO : merged Phrases<55276 vocab, min_count=1, threshold=1, max_vocab_size=40000000>
# 2022-10-25 16:50:22,801 : INFO : Phrases lifecycle event {'msg': 'built Phrases<55276 vocab, min_count=1, threshold=1, max_vocab_size=40000000> in 0.72s', 'datetime': '2022-10-25T16:50:22.801546', 'gensim': '4.1.2', 'python': '3.9.7 (default, Sep 16 2021, 08:50:36) \n[Clang 10.0.0 ]', 'platform': 'macOS-10.16-x86_64-i386-64bit', 'event': 'created'}

# %% [markdown]
# #### EDA: See how the trained model is working on unseen sentences

# %%
# Apply the trained phrases model to a new, unseen sentence.
new_sentence = ['tfgs', 'big', 'lie', 'to', 'steal', 'the', 'election', 'was', 'premeditated', 'months', 'before', 'the', 'election']

# %%
# Apply the trained phrases model to a new, unseen sentence.
# The toy model considered 'premeditated', 'months' a single phrase => joined the two
# tokens into a single "phrase" token, using our selected `_` delimiter.
bigram_mod[new_sentence]
# Out:
# ['tfgs',
#  'big_lie',
#  'to',
#  'steal_the_election',
#  'was',
#  'premeditated_months',
#  'before_the_election']

# %% [markdown]
# ### Define Functions: Remove Stopwords and Make Bigrams
# - lemmatization also included when necessary

# %%
def remove_stopwords(texts):
    return [[word for word in simple_preprocess(str(doc)) if word not in stop_words] for doc in texts]

def make_bigrams(texts):
    return [bigram_mod[doc] for doc in texts]

# def lemmatization(texts, allowed_postags=['NOUN', 'ADJ', 'VERB', 'ADV']):
#     """https://spacy.io/api/annotation"""
#     texts_out = []
#     for sent in texts:
#         doc = nlp(" ".join(sent)) 
#         texts_out.append([token.lemma_ for token in doc if token.pos_ in allowed_postags])
#     return texts_out

# %% [markdown]
# ### Call the functions in order

# %%
# Remove Stop Words
data_words_nostops = remove_stopwords(data_words)

# Form Bigrams
data_words_bigrams = make_bigrams(data_words_nostops)

# Initialize spacy 'en' model, keeping only tagger component (for efficiency)
# python3 -m spacy download en
#nlp = spacy.load('en', disable=['parser', 'ner'])
#nlp = spacy.load("en_core_web_sm")

# Do lemmatization keeping only noun, adj, vb, adv
#data_lemmatized = lemmatization(data_words_bigrams, allowed_postags=['NOUN', 'ADJ', 'VERB', 'ADV'])

# %%
print(data_words_bigrams[:1])
# Out:
# [['roevember', 'forthepeople', 'votebluein', 'oathbreakermaga']]

# %% [markdown]
# ### Prepare the Inputs for Modeling
# - two main inputs to the LDA topic model:
# - the dictionary (id2word) and
# -the corpus.

# %%
#Create Dictionary
#corpora module implements concept of dictionary between words and their integer ids 
id2word = corpora.Dictionary(data_words_bigrams)
# Out:
# 2022-10-25 16:57:09,040 : INFO : adding document #0 to Dictionary(0 unique tokens: [])
# 2022-10-25 16:57:09,165 : INFO : adding document #10000 to Dictionary(6011 unique tokens: ['forthepeople', 'oathbreakermaga', 'roevember', 'votebluein', 'defense_chris']...)
# 2022-10-25 16:57:09,285 : INFO : adding document #20000 to Dictionary(8721 unique tokens: ['forthepeople', 'oathbreakermaga', 'roevember', 'votebluein', 'defense_chris']...)
# 2022-10-25 16:57:09,409 : INFO : adding document #30000 to Dictionary(10585 unique tokens: ['forthepeople', 'oathbreakermaga', 'roevember', 'votebluein', 'defense_chris']...)
# 2022-10-25 16:57:09,476 : INFO : built Dictionary(11177 unique tokens: ['forthepeople', 'oathbreakermaga', 'roevember', 'votebluein', 'defense_chris']...) from 34993 documents (total 247325 corpus positions)
# 2022-10-25 16:57:09,477 : INFO : Dictionary lifecycle event {'msg': "built Dictionary(11177 unique tokens: ['forthepeople', 'oathbreakermaga', 'roevember', 'votebluein', 'defense_chris']...) from 34993 documents (total 247325 corpus positions)", 'datetime': '2022-10-25T16:57:09.477156', 'gensim': '4.1.2', 'python': '3.9.7 (default, Sep 16 2021, 08:50:36) \n[Clang 10.0.0 ]', 'platform': 'macOS-10.16-x86_64-i386-64bit', 'event': 'created'}

# %%
id2word[1]
# Out:
# 'oathbreakermaga'

# %% [markdown]
# #### Create bag of words corpus
# - corpus contains the word id and its frequency in every document https://www.tutorialspoint.com/gensim/gensim_creating_a_bag_of_words_corpus.htm
# - This is used as input into LDA model

# %%
# bag of words corpus
corpus2 = [id2word.doc2bow(text) for text in data_words_bigrams]

# %%
# View: Gensim creates a unique id for each word in the document. Tuples are word id, word frequency
# This is used as teh input by the LDA model. 
print(corpus2[:1])
# Out:
# [[(0, 1), (1, 1), (2, 1), (3, 1)]]

# %%
#to see what word a given id corresponds to, pass the id as a key to the dictionary
id2word[0]
# Out:
# 'forthepeople'

# %%
# Human readable format of corpus (term-frequency)
[[(id2word[id], freq) for id, freq in cp] for cp in corpus2[:1]]
# Out:
# [[('forthepeople', 1),
#   ('oathbreakermaga', 1),
#   ('roevember', 1),
#   ('votebluein', 1)]]

# %% [markdown]
# ### Jump back on track: Build the topic model
# - More on the parameters https://miningthedetails.com/blog/python/lda/GensimLDA/
# - passes: is the total number of training passes.
# - random_state: ({np.random.RandomState, int}, optional) – Either a randomState object or a seed to generate one. Useful for reproducibility.

# %%
lda_model = gensim.models.ldamodel.LdaModel(corpus=corpus2,
                                           id2word=id2word,
                                           num_topics=4, 
                                           random_state=100,
                                           passes=10)
# Out:
# 2022-10-25 17:43:12,323 : INFO : using symmetric alpha at 0.25
# 2022-10-25 17:43:12,325 : INFO : using symmetric eta at 0.25
# 2022-10-25 17:43:12,330 : INFO : using serial LDA version on this node
# 2022-10-25 17:43:12,341 : INFO : running online (multi-pass) LDA training, 4 topics, 10 passes over the supplied corpus of 34993 documents, updating model once every 2000 documents, evaluating perplexity every 20000 documents, iterating 50x with a convergence threshold of 0.001000
# 2022-10-25 17:43:12,342 : INFO : PROGRESS: pass 0, at document #2000/34993
# 2022-10-25 17:43:13,369 : INFO : merging changes from 2000 documents into a model of 34993 documents
# 2022-10-25 17:43:13,375 : INFO : topic #0 (0.250): 0.045*"knew" + 0.019*"donald_trump" + 0.016*"th" + 0.015*"trump" + 0.014*"nancy_pelosi" + 0.012*"tell" + 0.012*"otherwise" + 0.012*"let_cnn" + 0.012*"hates_steve" + 0.012*"clear"
# 2022-10-25 17:43:13,376 : INFO : topic #1 (0.250): 0.029*"th" + 0.028*"trump" + 0.020*"nancy_pelosi" + 0.019*"want" + 0.019*"service_leading" + 0.019*"chair_amp" + 0.019*"vice_chair" + 0.019*"thanks" + 0.019*"send_special" + 0.015*"donald_trump"
# 2022-10-25 17:43:13,377 : INFO : topic #2 (0.250): 0.033*"violence" + 0.024*"maga_gop" + 0.024*"correct" + 0.024*"overthrowing_democracy" + 0.023*"thcomm" + 0.023*"mark_hamill" + 0.022*"love" + 0.022*"country_without_creating" + 0.019*"trump" + 0.015*"oathbreakermaga"
# 2022-10-25 17:43:13,378 : INFO : topic #3 (0.250): 0.052*"knew_trump" + 0.052*"called" + 0.051*"kevin_mccarthy" + 0.051*"mitch_mcconnell" + 0.051*"backed" + 0.051*"responsible" + 0.020*"trump" + 0.020*"decided" + 0.013*"violence" + 0.011*"country_without_creating"
# 2022-10-25 17:43:13,378 : INFO : topic diff=5.027564, rho=1.000000
# 2022-10-25 17:43:13,379 : INFO : PROGRESS: pass 0, at document #4000/34993
# 2022-10-25 17:43:13,746 : INFO : merging changes from 2000 documents into a model of 34993 documents
# 2022-10-25 17:43:13,749 : INFO : topic #0 (0.250): 0.056*"knew" + 0.028*"th" + 0.027*"nancy_pelosi" + 0.023*"would" + 0.022*"hoax" + 0.022*"advance" + 0.022*"daughter_film" + 0.022*"protests" + 0.012*"trump" + 0.008*"donald_trump"
# 2022-10-25 17:43:13,751 : INFO : topic #1 (0.250): 0.035*"th" + 0.033*"trump" + 0.028*"want" + 0.026*"service_leading" + 0.026*"chair_amp" + 0.026*"vice_chair" + 0.026*"thanks" + 0.026*"send_special" + 0.015*"testify" + 0.014*"evidence"
# 2022-10-25 17:43:13,751 : INFO : topic #2 (0.250): 0.053*"violence" + 0.039*"maga_gop" + 0.039*"thcomm" + 0.038*"correct" + 0.038*"love" + 0.038*"overthrowing_democracy" + 0.038*"mark_hamill" + 0.038*"country_without_creating" + 0.022*"trump" + 0.016*"says"
# 2022-10-25 17:43:13,752 : INFO : topic #3 (0.250): 0.068*"called" + 0.068*"knew_trump" + 0.068*"kevin_mccarthy" + 0.068*"mitch_mcconnell" + 0.067*"backed" + 0.067*"responsible" + 0.025*"decided" + 0.016*"democracy" + 0.014*"loss" + 0.014*"accept"
# 2022-10-25 17:43:13,753 : INFO : topic diff=0.640869, rho=0.707107
# 2022-10-25 17:43:13,754 : INFO : PROGRESS: pass 0, at document #6000/34993
# 2022-10-25 17:43:14,068 : INFO : merging changes from 2000 documents into a model of 34993 documents
# 2022-10-25 17:43:14,072 : INFO : topic #0 (0.250): 0.049*"knew" + 0.016*"th" + 0.014*"would" + 0.014*"nancy_pelosi" + 0.013*"trump" + 0.010*"advance" + 0.010*"hoax" + 0.010*"daughter_film" + 0.010*"protests" + 0.009*"pelosi"
# 2022-10-25 17:43:14,073 : INFO : topic #1 (0.250): 0.040*"th" + 0.035*"want" + 0.033*"thanks" + 0.032*"trump" + 0.032*"service_leading" + 0.032*"chair_amp" + 0.032*"vice_chair" + 0.032*"send_special" + 0.013*"testify" + 0.013*"evidence"
# 2022-10-25 17:43:14,075 : INFO : topic #2 (0.250): 0.063*"violence" + 0.046*"maga_gop" + 0.046*"thcomm" + 0.046*"love" + 0.045*"correct" + 0.045*"overthrowing_democracy" + 0.045*"mark_hamill" + 0.045*"country_without_creating" + 0.024*"trump" + 0.017*"says"
# 2022-10-25 17:43:14,076 : INFO : topic #3 (0.250): 0.073*"called" + 0.073*"knew_trump" + 0.073*"kevin_mccarthy" + 0.073*"mitch_mcconnell" + 0.073*"backed" + 0.072*"responsible" + 0.022*"decided" + 0.017*"democracy" + 0.014*"accept" + 0.014*"american_people"
# 2022-10-25 17:43:14,076 : INFO : topic diff=0.527698, rho=0.577350
# 2022-10-25 17:43:14,078 : INFO : PROGRESS: pass 0, at document #8000/34993
# 2022-10-25 17:43:14,355 : INFO : merging changes from 2000 documents into a model of 34993 documents
# 2022-10-25 17:43:14,359 : INFO : topic #0 (0.250): 0.044*"knew" + 0.016*"trump" + 0.009*"would" + 0.009*"th" + 0.009*"pelosi" + 0.008*"nancy_pelosi" + 0.008*"held" + 0.008*"donald_trump" + 0.008*"see" + 0.007*"setup"
# 2022-10-25 17:43:14,360 : INFO : topic #1 (0.250): 0.036*"th" + 0.036*"trump" + 0.033*"want" + 0.030*"thanks" + 0.029*"service_leading" + 0.029*"chair_amp" + 0.029*"vice_chair" + 0.029*"send_special" + 0.015*"testify" + 0.014*"evidence"
# 2022-10-25 17:43:14,361 : INFO : topic #2 (0.250): 0.069*"violence" + 0.052*"thcomm" + 0.052*"maga_gop" + 0.052*"love" + 0.051*"correct" + 0.051*"overthrowing_democracy" + 0.051*"mark_hamill" + 0.051*"country_without_creating" + 0.026*"trump" + 0.020*"says"
# 2022-10-25 17:43:14,362 : INFO : topic #3 (0.250): 0.081*"responsible" + 0.081*"called" + 0.081*"kevin_mccarthy" + 0.081*"knew_trump" + 0.081*"mitch_mcconnell" + 0.081*"backed" + 0.022*"decided" + 0.016*"democracy" + 0.013*"american_people" + 0.013*"accept"
# 2022-10-25 17:43:14,363 : INFO : topic diff=0.443058, rho=0.500000
# 2022-10-25 17:43:14,364 : INFO : PROGRESS: pass 0, at document #10000/34993
# 2022-10-25 17:43:14,622 : INFO : merging changes from 2000 documents into a model of 34993 documents
# 2022-10-25 17:43:14,625 : INFO : topic #0 (0.250): 0.042*"knew" + 0.018*"trump" + 0.010*"donald_trump" + 0.009*"act" + 0.009*"held" + 0.009*"violent_armed" + 0.008*"plans" + 0.008*"pelosi" + 0.008*"reason_law" + 0.008*"warnings"
# 2022-10-25 17:43:14,626 : INFO : topic #1 (0.250): 0.040*"trump" + 0.039*"th" + 0.037*"want" + 0.033*"thanks" + 0.032*"service_leading" + 0.032*"chair_amp" + 0.032*"vice_chair" + 0.032*"send_special" + 0.018*"testify" + 0.017*"voted_unanimously"
# 2022-10-25 17:43:14,627 : INFO : topic #2 (0.250): 0.071*"violence" + 0.050*"love" + 0.050*"thcomm" + 0.050*"maga_gop" + 0.050*"correct" + 0.050*"overthrowing_democracy" + 0.050*"mark_hamill" + 0.050*"country_without_creating" + 0.032*"trump" + 0.021*"says"
# 2022-10-25 17:43:14,628 : INFO : topic #3 (0.250): 0.081*"called" + 0.081*"kevin_mccarthy" + 0.081*"responsible" + 0.081*"mitch_mcconnell" + 0.081*"knew_trump" + 0.080*"backed" + 0.026*"decided" + 0.015*"democracy" + 0.014*"trump_lost" + 0.014*"trump_tried"
# 2022-10-25 17:43:14,629 : INFO : topic diff=0.324112, rho=0.447214
# 2022-10-25 17:43:14,630 : INFO : PROGRESS: pass 0, at document #12000/34993
# 2022-10-25 17:43:14,906 : INFO : merging changes from 2000 documents into a model of 34993 documents
# 2022-10-25 17:43:14,910 : INFO : topic #0 (0.250): 0.035*"knew" + 0.019*"trump" + 0.010*"act" + 0.010*"violent_armed" + 0.010*"plans" + 0.010*"democracy" + 0.009*"reason_law" + 0.009*"warnings" + 0.009*"flood" + 0.009*"ins"
# 2022-10-25 17:43:14,911 : INFO : topic #1 (0.250): 0.044*"trump" + 0.029*"th" + 0.028*"want" + 0.021*"thanks" + 0.020*"vice_chair" + 0.020*"service_leading" + 0.020*"chair_amp" + 0.020*"send_special" + 0.019*"testify" + 0.018*"voted_unanimously"
# 2022-10-25 17:43:14,912 : INFO : topic #2 (0.250): 0.070*"violence" + 0.048*"thcomm" + 0.047*"love" + 0.047*"maga_gop" + 0.046*"correct" + 0.046*"overthrowing_democracy" + 0.046*"mark_hamill" + 0.046*"country_without_creating" + 0.033*"trump" + 0.024*"says"
# 2022-10-25 17:43:14,913 : INFO : topic #3 (0.250): 0.080*"called" + 0.080*"kevin_mccarthy" + 0.080*"responsible" + 0.079*"mitch_mcconnell" + 0.079*"knew_trump" + 0.079*"backed" + 0.028*"decided" + 0.017*"trump_lost" + 0.016*"roger_stone" + 0.015*"help"
# 2022-10-25 17:43:14,914 : INFO : topic diff=0.398025, rho=0.408248
# 2022-10-25 17:43:14,914 : INFO : PROGRESS: pass 0, at document #14000/34993
# 2022-10-25 17:43:15,191 : INFO : merging changes from 2000 documents into a model of 34993 documents
# 2022-10-25 17:43:15,196 : INFO : topic #0 (0.250): 0.044*"knew" + 0.026*"trump" + 0.010*"election" + 0.009*"violent_armed" + 0.009*"act" + 0.009*"plans" + 0.009*"reason_law" + 0.009*"warnings" + 0.009*"flood" + 0.009*"ins"
# 2022-10-25 17:43:15,197 : INFO : topic #1 (0.250): 0.050*"trump" + 0.023*"th" + 0.021*"want" + 0.020*"testify" + 0.020*"subpoena_donald" + 0.019*"voted_unanimously" + 0.018*"demands" + 0.018*"history_deserves" + 0.018*"oath_democracy" + 0.014*"thanks"
# 2022-10-25 17:43:15,199 : INFO : topic #2 (0.250): 0.064*"violence" + 0.040*"thcomm" + 0.040*"love" + 0.040*"maga_gop" + 0.039*"correct" + 0.039*"overthrowing_democracy" + 0.039*"mark_hamill" + 0.039*"country_without_creating" + 0.037*"trump" + 0.024*"says"
# 2022-10-25 17:43:15,200 : INFO : topic #3 (0.250): 0.079*"called" + 0.079*"kevin_mccarthy" + 0.078*"responsible" + 0.078*"mitch_mcconnell" + 0.078*"knew_trump" + 0.078*"backed" + 0.029*"decided" + 0.018*"trump_lost" + 0.018*"roger_stone" + 0.018*"yet"
# 2022-10-25 17:43:15,200 : INFO : topic diff=0.348380, rho=0.377964
# 2022-10-25 17:43:15,202 : INFO : PROGRESS: pass 0, at document #16000/34993
# 2022-10-25 17:43:15,468 : INFO : merging changes from 2000 documents into a model of 34993 documents
# 2022-10-25 17:43:15,472 : INFO : topic #0 (0.250): 0.050*"knew" + 0.030*"trump" + 0.012*"election" + 0.010*"lost" + 0.009*"pelosi" + 0.009*"held" + 0.009*"donald_trump" + 0.008*"violent_armed" + 0.008*"happened" + 0.008*"act"
# 2022-10-25 17:43:15,473 : INFO : topic #1 (0.250): 0.047*"trump" + 0.021*"th" + 0.020*"subpoena_donald" + 0.020*"testify" + 0.019*"voted_unanimously" + 0.019*"demands" + 0.019*"history_deserves" + 0.019*"oath_democracy" + 0.015*"want" + 0.009*"thanks"
# 2022-10-25 17:43:15,474 : INFO : topic #2 (0.250): 0.065*"violence" + 0.040*"love" + 0.040*"thcomm" + 0.039*"maga_gop" + 0.039*"correct" + 0.039*"overthrowing_democracy" + 0.039*"mark_hamill" + 0.039*"country_without_creating" + 0.038*"trump" + 0.023*"says"
# 2022-10-25 17:43:15,476 : INFO : topic #3 (0.250): 0.088*"called" + 0.086*"responsible" + 0.086*"kevin_mccarthy" + 0.086*"knew_trump" + 0.086*"mitch_mcconnell" + 0.086*"backed" + 0.027*"decided" + 0.017*"trump_lost" + 0.017*"roger_stone" + 0.016*"help"
# 2022-10-25 17:43:15,477 : INFO : topic diff=0.316015, rho=0.353553
# 2022-10-25 17:43:15,478 : INFO : PROGRESS: pass 0, at document #18000/34993
# 2022-10-25 17:43:15,737 : INFO : merging changes from 2000 documents into a model of 34993 documents
# 2022-10-25 17:43:15,741 : INFO : topic #0 (0.250): 0.053*"knew" + 0.032*"trump" + 0.012*"election" + 0.010*"lost" + 0.009*"donald_trump" + 0.008*"pelosi" + 0.008*"happened" + 0.008*"held" + 0.008*"testified" + 0.007*"violent_armed"
# 2022-10-25 17:43:15,742 : INFO : topic #1 (0.250): 0.051*"trump" + 0.024*"testify" + 0.024*"subpoena_donald" + 0.023*"voted_unanimously" + 0.022*"demands" + 0.022*"history_deserves" + 0.022*"oath_democracy" + 0.015*"th" + 0.011*"want" + 0.008*"going"
# 2022-10-25 17:43:15,743 : INFO : topic #2 (0.250): 0.062*"violence" + 0.038*"thcomm" + 0.038*"trump" + 0.038*"love" + 0.037*"maga_gop" + 0.036*"correct" + 0.036*"overthrowing_democracy" + 0.036*"mark_hamill" + 0.036*"country_without_creating" + 0.022*"says"
# 2022-10-25 17:43:15,744 : INFO : topic #3 (0.250): 0.085*"called" + 0.083*"responsible" + 0.083*"mitch_mcconnell" + 0.083*"kevin_mccarthy" + 0.083*"knew_trump" + 0.083*"backed" + 0.029*"decided" + 0.018*"trump_lost" + 0.018*"roger_stone" + 0.017*"yet"
# 2022-10-25 17:43:15,745 : INFO : topic diff=0.347590, rho=0.333333
# 2022-10-25 17:43:16,175 : INFO : -6.623 per-word bound, 98.5 perplexity estimate based on a held-out corpus of 2000 documents with 14458 words
# 2022-10-25 17:43:16,176 : INFO : PROGRESS: pass 0, at document #20000/34993
# 2022-10-25 17:43:16,445 : INFO : merging changes from 2000 documents into a model of 34993 documents
# 2022-10-25 17:43:16,449 : INFO : topic #0 (0.250): 0.052*"knew" + 0.032*"trump" + 0.011*"election" + 0.010*"lost" + 0.009*"donald_trump" + 0.009*"happened" + 0.008*"pelosi" + 0.008*"violent_armed" + 0.008*"testified" + 0.007*"supporters"
# 2022-10-25 17:43:16,450 : INFO : topic #1 (0.250): 0.053*"trump" + 0.024*"subpoena_donald" + 0.024*"testify" + 0.023*"voted_unanimously" + 0.023*"demands" + 0.023*"history_deserves" + 0.023*"oath_democracy" + 0.014*"th" + 0.010*"want" + 0.009*"going"
# 2022-10-25 17:43:16,451 : INFO : topic #2 (0.250): 0.061*"violence" + 0.037*"trump" + 0.035*"thcomm" + 0.035*"love" + 0.034*"maga_gop" + 0.033*"correct" + 0.033*"overthrowing_democracy" + 0.033*"mark_hamill" + 0.033*"country_without_creating" + 0.021*"says"
# 2022-10-25 17:43:16,452 : INFO : topic #3 (0.250): 0.080*"called" + 0.079*"responsible" + 0.079*"mitch_mcconnell" + 0.079*"kevin_mccarthy" + 0.079*"knew_trump" + 0.079*"backed" + 0.031*"decided" + 0.018*"trump_lost" + 0.018*"roger_stone" + 0.017*"yet"
# 2022-10-25 17:43:16,453 : INFO : topic diff=0.341821, rho=0.316228
# 2022-10-25 17:43:16,454 : INFO : PROGRESS: pass 0, at document #22000/34993
# 2022-10-25 17:43:16,721 : INFO : merging changes from 2000 documents into a model of 34993 documents
# 2022-10-25 17:43:16,725 : INFO : topic #0 (0.250): 0.048*"knew" + 0.030*"trump" + 0.011*"happened" + 0.010*"violent_armed" + 0.010*"testified" + 0.009*"election" + 0.009*"act" + 0.009*"lost" + 0.009*"hours" + 0.009*"ev"
# 2022-10-25 17:43:16,726 : INFO : topic #1 (0.250): 0.054*"trump" + 0.026*"subpoena_donald" + 0.025*"testify" + 0.024*"voted_unanimously" + 0.024*"demands" + 0.024*"history_deserves" + 0.024*"oath_democracy" + 0.013*"th" + 0.010*"going" + 0.008*"want"
# 2022-10-25 17:43:16,727 : INFO : topic #2 (0.250): 0.059*"violence" + 0.042*"trump" + 0.032*"thcomm" + 0.031*"love" + 0.030*"maga_gop" + 0.030*"correct" + 0.030*"overthrowing_democracy" + 0.030*"mark_hamill" + 0.030*"country_without_creating" + 0.022*"th_attack"
# 2022-10-25 17:43:16,729 : INFO : topic #3 (0.250): 0.076*"called" + 0.075*"responsible" + 0.075*"mitch_mcconnell" + 0.075*"knew_trump" + 0.075*"kevin_mccarthy" + 0.075*"backed" + 0.035*"decided" + 0.022*"roger_stone" + 0.021*"trump_lost" + 0.021*"help"
# 2022-10-25 17:43:16,729 : INFO : topic diff=0.300772, rho=0.301511
# 2022-10-25 17:43:16,730 : INFO : PROGRESS: pass 0, at document #24000/34993
# 2022-10-25 17:43:16,985 : INFO : merging changes from 2000 documents into a model of 34993 documents
# 2022-10-25 17:43:16,989 : INFO : topic #0 (0.250): 0.052*"knew" + 0.029*"trump" + 0.012*"happened" + 0.011*"violent_armed" + 0.011*"donald_trump" + 0.010*"testified" + 0.010*"hours" + 0.009*"ev" + 0.009*"afraid" + 0.009*"trump_get"
# 2022-10-25 17:43:16,991 : INFO : topic #1 (0.250): 0.054*"trump" + 0.026*"subpoena_donald" + 0.025*"testify" + 0.024*"voted_unanimously" + 0.023*"demands" + 0.023*"history_deserves" + 0.023*"oath_democracy" + 0.012*"th" + 0.009*"going" + 0.007*"want"
# 2022-10-25 17:43:16,991 : INFO : topic #2 (0.250): 0.058*"violence" + 0.039*"trump" + 0.030*"thcomm" + 0.029*"love" + 0.028*"maga_gop" + 0.028*"correct" + 0.028*"overthrowing_democracy" + 0.028*"mark_hamill" + 0.028*"country_without_creating" + 0.022*"th_attack"
# 2022-10-25 17:43:16,992 : INFO : topic #3 (0.250): 0.075*"called" + 0.074*"knew_trump" + 0.074*"kevin_mccarthy" + 0.074*"mitch_mcconnell" + 0.074*"responsible" + 0.074*"backed" + 0.034*"decided" + 0.022*"roger_stone" + 0.022*"trump_lost" + 0.022*"help"
# 2022-10-25 17:43:16,993 : INFO : topic diff=0.281719, rho=0.288675
# 2022-10-25 17:43:16,994 : INFO : PROGRESS: pass 0, at document #26000/34993
# 2022-10-25 17:43:17,280 : INFO : merging changes from 2000 documents into a model of 34993 documents
# 2022-10-25 17:43:17,284 : INFO : topic #0 (0.250): 0.050*"knew" + 0.027*"trump" + 0.013*"violent_armed" + 0.013*"happened" + 0.012*"act" + 0.011*"testified" + 0.011*"plans" + 0.011*"reason_law" + 0.011*"warnings" + 0.011*"flood"
# 2022-10-25 17:43:17,285 : INFO : topic #1 (0.250): 0.055*"trump" + 0.028*"subpoena_donald" + 0.028*"testify" + 0.026*"voted_unanimously" + 0.026*"demands" + 0.026*"history_deserves" + 0.026*"oath_democracy" + 0.011*"th" + 0.010*"going" + 0.007*"want"
# 2022-10-25 17:43:17,286 : INFO : topic #2 (0.250): 0.054*"violence" + 0.038*"trump" + 0.026*"thcomm" + 0.025*"love" + 0.025*"maga_gop" + 0.024*"correct" + 0.024*"overthrowing_democracy" + 0.024*"mark_hamill" + 0.024*"country_without_creating" + 0.023*"th_attack"
# 2022-10-25 17:43:17,287 : INFO : topic #3 (0.250): 0.071*"called" + 0.071*"knew_trump" + 0.070*"mitch_mcconnell" + 0.070*"responsible" + 0.070*"kevin_mccarthy" + 0.070*"backed" + 0.035*"decided" + 0.025*"roger_stone" + 0.024*"trump_lost" + 0.024*"help"
# 2022-10-25 17:43:17,288 : INFO : topic diff=0.264663, rho=0.277350
# 2022-10-25 17:43:17,289 : INFO : PROGRESS: pass 0, at document #28000/34993
# 2022-10-25 17:43:17,570 : INFO : merging changes from 2000 documents into a model of 34993 documents
# 2022-10-25 17:43:17,574 : INFO : topic #0 (0.250): 0.049*"knew" + 0.025*"trump" + 0.015*"violent_armed" + 0.014*"happened" + 0.013*"act" + 0.013*"plans" + 0.013*"reason_law" + 0.013*"warnings" + 0.013*"flood" + 0.013*"ins"
# 2022-10-25 17:43:17,574 : INFO : topic #1 (0.250): 0.051*"trump" + 0.025*"subpoena_donald" + 0.025*"testify" + 0.024*"voted_unanimously" + 0.024*"demands" + 0.024*"history_deserves" + 0.024*"oath_democracy" + 0.010*"th" + 0.008*"going" + 0.008*"social_media"
# 2022-10-25 17:43:17,575 : INFO : topic #2 (0.250): 0.052*"violence" + 0.038*"trump" + 0.024*"thcomm" + 0.024*"love" + 0.024*"th_attack" + 0.023*"trump_summoned" + 0.023*"goaded" + 0.023*"author" + 0.023*"maga_gop" + 0.023*"rioters_trump"
# 2022-10-25 17:43:17,577 : INFO : topic #3 (0.250): 0.070*"called" + 0.070*"knew_trump" + 0.070*"responsible" + 0.070*"mitch_mcconnell" + 0.070*"kevin_mccarthy" + 0.069*"backed" + 0.035*"decided" + 0.026*"roger_stone" + 0.025*"trump_lost" + 0.025*"help"
# 2022-10-25 17:43:17,578 : INFO : topic diff=0.302948, rho=0.267261
# 2022-10-25 17:43:17,579 : INFO : PROGRESS: pass 0, at document #30000/34993
# 2022-10-25 17:43:17,849 : INFO : merging changes from 2000 documents into a model of 34993 documents
# 2022-10-25 17:43:17,853 : INFO : topic #0 (0.250): 0.044*"knew" + 0.024*"trump" + 0.015*"happened" + 0.014*"violent_armed" + 0.013*"act" + 0.013*"testified" + 0.012*"plans" + 0.012*"reason_law" + 0.012*"warnings" + 0.012*"flood"
# 2022-10-25 17:43:17,855 : INFO : topic #1 (0.250): 0.053*"trump" + 0.026*"testify" + 0.026*"subpoena_donald" + 0.025*"voted_unanimously" + 0.024*"demands" + 0.024*"history_deserves" + 0.024*"oath_democracy" + 0.009*"th" + 0.009*"going" + 0.006*"end"
# 2022-10-25 17:43:17,856 : INFO : topic #2 (0.250): 0.055*"violence" + 0.040*"trump" + 0.026*"th_attack" + 0.026*"trump_summoned" + 0.026*"goaded" + 0.026*"author" + 0.026*"rioters_trump" + 0.026*"trump_excuse" + 0.025*"thcomm" + 0.024*"love"
# 2022-10-25 17:43:17,857 : INFO : topic #3 (0.250): 0.069*"called" + 0.068*"knew_trump" + 0.068*"responsible" + 0.068*"mitch_mcconnell" + 0.068*"kevin_mccarthy" + 0.068*"backed" + 0.034*"decided" + 0.026*"roger_stone" + 0.025*"trump_lost" + 0.024*"help"
# 2022-10-25 17:43:17,858 : INFO : topic diff=0.263277, rho=0.258199
# 2022-10-25 17:43:17,859 : INFO : PROGRESS: pass 0, at document #32000/34993
# 2022-10-25 17:43:18,171 : INFO : merging changes from 2000 documents into a model of 34993 documents
# 2022-10-25 17:43:18,175 : INFO : topic #0 (0.250): 0.048*"knew" + 0.023*"trump" + 0.017*"happened" + 0.015*"testified" + 0.014*"afraid" + 0.014*"violent_armed" + 0.014*"ev" + 0.014*"hours" + 0.014*"trump_get" + 0.014*"biggest_audience"
# 2022-10-25 17:43:18,180 : INFO : topic #1 (0.250): 0.056*"trump" + 0.026*"testify" + 0.026*"subpoena_donald" + 0.025*"voted_unanimously" + 0.025*"demands" + 0.025*"history_deserves" + 0.025*"oath_democracy" + 0.010*"going" + 0.008*"th" + 0.007*"end"
# 2022-10-25 17:43:18,185 : INFO : topic #2 (0.250): 0.056*"violence" + 0.042*"trump" + 0.027*"trump_summoned" + 0.027*"th_attack" + 0.027*"goaded" + 0.027*"author" + 0.027*"rioters_trump" + 0.027*"trump_excuse" + 0.024*"thcomm" + 0.024*"love"
# 2022-10-25 17:43:18,188 : INFO : topic #3 (0.250): 0.071*"called" + 0.071*"responsible" + 0.071*"knew_trump" + 0.071*"mitch_mcconnell" + 0.071*"kevin_mccarthy" + 0.071*"backed" + 0.031*"decided" + 0.024*"roger_stone" + 0.024*"trump_lost" + 0.022*"help"
# 2022-10-25 17:43:18,190 : INFO : topic diff=0.225436, rho=0.250000
# 2022-10-25 17:43:18,192 : INFO : PROGRESS: pass 0, at document #34000/34993
# 2022-10-25 17:43:18,478 : INFO : merging changes from 2000 documents into a model of 34993 documents
# 2022-10-25 17:43:18,483 : INFO : topic #0 (0.250): 0.050*"knew" + 0.022*"trump" + 0.017*"happened" + 0.015*"testified" + 0.014*"afraid" + 0.014*"hours" + 0.014*"ev" + 0.014*"trump_get" + 0.014*"biggest_audience" + 0.014*"hey_trump"
# 2022-10-25 17:43:18,484 : INFO : topic #1 (0.250): 0.058*"trump" + 0.028*"subpoena_donald" + 0.028*"testify" + 0.027*"voted_unanimously" + 0.027*"demands" + 0.026*"history_deserves" + 0.026*"oath_democracy" + 0.009*"going" + 0.008*"th" + 0.007*"want"
# 2022-10-25 17:43:18,485 : INFO : topic #2 (0.250): 0.054*"violence" + 0.043*"trump" + 0.027*"trump_summoned" + 0.027*"th_attack" + 0.027*"goaded" + 0.027*"author" + 0.027*"rioters_trump" + 0.027*"trump_excuse" + 0.023*"thcomm" + 0.022*"love"
# 2022-10-25 17:43:18,487 : INFO : topic #3 (0.250): 0.073*"mitch_mcconnell" + 0.073*"called" + 0.073*"responsible" + 0.073*"knew_trump" + 0.073*"kevin_mccarthy" + 0.073*"backed" + 0.029*"decided" + 0.023*"roger_stone" + 0.022*"trump_lost" + 0.021*"help"
# 2022-10-25 17:43:18,487 : INFO : topic diff=0.200089, rho=0.242536
# 2022-10-25 17:43:18,705 : INFO : -6.229 per-word bound, 75.0 perplexity estimate based on a held-out corpus of 993 documents with 6779 words
# 2022-10-25 17:43:18,706 : INFO : PROGRESS: pass 0, at document #34993/34993
# 2022-10-25 17:43:18,838 : INFO : merging changes from 993 documents into a model of 34993 documents
# 2022-10-25 17:43:18,842 : INFO : topic #0 (0.250): 0.044*"knew" + 0.019*"trump" + 0.016*"happened" + 0.015*"testified" + 0.014*"hours" + 0.014*"afraid" + 0.014*"ev" + 0.014*"trump_get" + 0.014*"biggest_audience" + 0.014*"hey_trump"
# 2022-10-25 17:43:18,843 : INFO : topic #1 (0.250): 0.059*"trump" + 0.030*"subpoena_donald" + 0.030*"testify" + 0.029*"voted_unanimously" + 0.028*"demands" + 0.028*"history_deserves" + 0.028*"oath_democracy" + 0.009*"going" + 0.007*"th" + 0.007*"watch"
# 2022-10-25 17:43:18,845 : INFO : topic #2 (0.250): 0.055*"violence" + 0.045*"trump" + 0.030*"trump_summoned" + 0.029*"th_attack" + 0.029*"goaded" + 0.029*"author" + 0.029*"rioters_trump" + 0.029*"trump_excuse" + 0.024*"shit" + 0.023*"heavy"
# 2022-10-25 17:43:18,846 : INFO : topic #3 (0.250): 0.073*"called" + 0.073*"mitch_mcconnell" + 0.073*"knew_trump" + 0.073*"responsible" + 0.073*"kevin_mccarthy" + 0.073*"backed" + 0.027*"decided" + 0.021*"roger_stone" + 0.021*"trump_lost" + 0.020*"thing"
# 2022-10-25 17:43:18,846 : INFO : topic diff=0.188214, rho=0.235702
# 2022-10-25 17:43:18,847 : INFO : PROGRESS: pass 1, at document #2000/34993
# 2022-10-25 17:43:19,126 : INFO : merging changes from 2000 documents into a model of 34993 documents
# 2022-10-25 17:43:19,131 : INFO : topic #0 (0.250): 0.047*"knew" + 0.018*"trump" + 0.014*"happened" + 0.013*"testified" + 0.013*"afraid" + 0.012*"hours" + 0.012*"ev" + 0.012*"trump_get" + 0.012*"biggest_audience" + 0.012*"hey_trump"
# 2022-10-25 17:43:19,132 : INFO : topic #1 (0.250): 0.054*"trump" + 0.025*"testify" + 0.025*"subpoena_donald" + 0.024*"voted_unanimously" + 0.023*"demands" + 0.023*"history_deserves" + 0.023*"oath_democracy" + 0.012*"th" + 0.010*"going" + 0.009*"want"
# 2022-10-25 17:43:19,133 : INFO : topic #2 (0.250): 0.058*"violence" + 0.039*"trump" + 0.029*"thcomm" + 0.028*"love" + 0.028*"maga_gop" + 0.027*"correct" + 0.027*"overthrowing_democracy" + 0.027*"mark_hamill" + 0.027*"country_without_creating" + 0.025*"trump_summoned"
# 2022-10-25 17:43:19,134 : INFO : topic #3 (0.250): 0.075*"called" + 0.075*"responsible" + 0.075*"mitch_mcconnell" + 0.075*"knew_trump" + 0.075*"kevin_mccarthy" + 0.075*"backed" + 0.028*"decided" + 0.020*"roger_stone" + 0.019*"trump_lost" + 0.019*"help"
# 2022-10-25 17:43:19,135 : INFO : topic diff=0.286401, rho=0.226476
# 2022-10-25 17:43:19,135 : INFO : PROGRESS: pass 1, at document #4000/34993
# 2022-10-25 17:43:19,409 : INFO : merging changes from 2000 documents into a model of 34993 documents
# 2022-10-25 17:43:19,413 : INFO : topic #0 (0.250): 0.048*"knew" + 0.016*"trump" + 0.014*"nancy_pelosi" + 0.012*"happened" + 0.011*"would" + 0.011*"testified" + 0.011*"th" + 0.010*"afraid" + 0.010*"hours" + 0.010*"ev"
# 2022-10-25 17:43:19,414 : INFO : topic #1 (0.250): 0.051*"trump" + 0.023*"testify" + 0.022*"subpoena_donald" + 0.021*"voted_unanimously" + 0.020*"demands" + 0.020*"history_deserves" + 0.020*"oath_democracy" + 0.017*"th" + 0.013*"want" + 0.010*"going"
# 2022-10-25 17:43:19,415 : INFO : topic #2 (0.250): 0.061*"violence" + 0.035*"trump" + 0.035*"thcomm" + 0.033*"love" + 0.033*"maga_gop" + 0.033*"correct" + 0.033*"overthrowing_democracy" + 0.033*"mark_hamill" + 0.033*"country_without_creating" + 0.023*"trump_summoned"
# 2022-10-25 17:43:19,415 : INFO : topic #3 (0.250): 0.077*"called" + 0.077*"responsible" + 0.077*"mitch_mcconnell" + 0.077*"knew_trump" + 0.077*"kevin_mccarthy" + 0.077*"backed" + 0.028*"decided" + 0.019*"roger_stone" + 0.018*"trump_lost" + 0.018*"help"
# 2022-10-25 17:43:19,416 : INFO : topic diff=0.256456, rho=0.226476
# 2022-10-25 17:43:19,418 : INFO : PROGRESS: pass 1, at document #6000/34993
# 2022-10-25 17:43:19,676 : INFO : merging changes from 2000 documents into a model of 34993 documents
# 2022-10-25 17:43:19,681 : INFO : topic #0 (0.250): 0.046*"knew" + 0.015*"trump" + 0.013*"nancy_pelosi" + 0.012*"would" + 0.011*"happened" + 0.010*"testified" + 0.009*"th" + 0.009*"afraid" + 0.009*"hours" + 0.009*"donald_trump"
# 2022-10-25 17:43:19,682 : INFO : topic #1 (0.250): 0.047*"trump" + 0.022*"th" + 0.020*"testify" + 0.019*"want" + 0.019*"subpoena_donald" + 0.018*"voted_unanimously" + 0.017*"demands" + 0.017*"history_deserves" + 0.017*"oath_democracy" + 0.014*"thanks"
# 2022-10-25 17:43:19,683 : INFO : topic #2 (0.250): 0.065*"violence" + 0.040*"thcomm" + 0.039*"love" + 0.039*"maga_gop" + 0.038*"correct" + 0.038*"overthrowing_democracy" + 0.038*"mark_hamill" + 0.038*"country_without_creating" + 0.033*"trump" + 0.021*"trump_summoned"
# 2022-10-25 17:43:19,684 : INFO : topic #3 (0.250): 0.079*"called" + 0.079*"responsible" + 0.079*"mitch_mcconnell" + 0.079*"knew_trump" + 0.079*"kevin_mccarthy" + 0.079*"backed" + 0.027*"decided" + 0.017*"roger_stone" + 0.016*"trump_lost" + 0.016*"help"
# 2022-10-25 17:43:19,686 : INFO : topic diff=0.285985, rho=0.226476
# 2022-10-25 17:43:19,689 : INFO : PROGRESS: pass 1, at document #8000/34993
# 2022-10-25 17:43:19,957 : INFO : merging changes from 2000 documents into a model of 34993 documents
# 2022-10-25 17:43:19,962 : INFO : topic #0 (0.250): 0.044*"knew" + 0.015*"trump" + 0.012*"nancy_pelosi" + 0.011*"would" + 0.009*"happened" + 0.009*"setup" + 0.009*"donald_trump" + 0.008*"testified" + 0.008*"th" + 0.008*"afraid"
# 2022-10-25 17:43:19,963 : INFO : topic #1 (0.250): 0.046*"trump" + 0.024*"th" + 0.020*"want" + 0.019*"testify" + 0.017*"subpoena_donald" + 0.017*"voted_unanimously" + 0.016*"thanks" + 0.016*"demands" + 0.016*"history_deserves" + 0.016*"oath_democracy"
# 2022-10-25 17:43:19,964 : INFO : topic #2 (0.250): 0.069*"violence" + 0.045*"thcomm" + 0.044*"love" + 0.044*"maga_gop" + 0.043*"correct" + 0.043*"overthrowing_democracy" + 0.043*"mark_hamill" + 0.043*"country_without_creating" + 0.031*"trump" + 0.019*"trump_summoned"
# 2022-10-25 17:43:19,965 : INFO : topic #3 (0.250): 0.083*"responsible" + 0.083*"called" + 0.082*"kevin_mccarthy" + 0.082*"mitch_mcconnell" + 0.082*"knew_trump" + 0.082*"backed" + 0.026*"decided" + 0.016*"roger_stone" + 0.015*"thing" + 0.015*"trump_lost"
# 2022-10-25 17:43:19,966 : INFO : topic diff=0.247823, rho=0.226476
# 2022-10-25 17:43:19,967 : INFO : PROGRESS: pass 1, at document #10000/34993
# 2022-10-25 17:43:20,219 : INFO : merging changes from 2000 documents into a model of 34993 documents
# 2022-10-25 17:43:20,223 : INFO : topic #0 (0.250): 0.043*"knew" + 0.016*"trump" + 0.011*"nancy_pelosi" + 0.009*"donald_trump" + 0.009*"happened" + 0.009*"would" + 0.008*"violent_armed" + 0.008*"testified" + 0.008*"act" + 0.008*"setup"
# 2022-10-25 17:43:20,224 : INFO : topic #1 (0.250): 0.046*"trump" + 0.027*"th" + 0.024*"want" + 0.020*"thanks" + 0.020*"vice_chair" + 0.020*"service_leading" + 0.020*"send_special" + 0.020*"chair_amp" + 0.019*"testify" + 0.018*"subpoena_donald"
# 2022-10-25 17:43:20,225 : INFO : topic #2 (0.250): 0.071*"violence" + 0.046*"thcomm" + 0.046*"love" + 0.045*"maga_gop" + 0.045*"correct" + 0.045*"overthrowing_democracy" + 0.045*"mark_hamill" + 0.045*"country_without_creating" + 0.033*"trump" + 0.021*"trump_summoned"
# 2022-10-25 17:43:20,226 : INFO : topic #3 (0.250): 0.083*"called" + 0.082*"responsible" + 0.082*"kevin_mccarthy" + 0.082*"mitch_mcconnell" + 0.082*"knew_trump" + 0.082*"backed" + 0.028*"decided" + 0.017*"roger_stone" + 0.016*"trump_lost" + 0.016*"help"
# 2022-10-25 17:43:20,227 : INFO : topic diff=0.195810, rho=0.226476
# 2022-10-25 17:43:20,228 : INFO : PROGRESS: pass 1, at document #12000/34993
# 2022-10-25 17:43:20,463 : INFO : merging changes from 2000 documents into a model of 34993 documents
# 2022-10-25 17:43:20,467 : INFO : topic #0 (0.250): 0.038*"knew" + 0.017*"trump" + 0.009*"happened" + 0.009*"donald_trump" + 0.009*"violent_armed" + 0.009*"nancy_pelosi" + 0.009*"act" + 0.009*"testified" + 0.008*"democracy" + 0.008*"plans"
# 2022-10-25 17:43:20,468 : INFO : topic #1 (0.250): 0.047*"trump" + 0.023*"th" + 0.022*"want" + 0.018*"testify" + 0.018*"voted_unanimously" + 0.018*"subpoena_donald" + 0.017*"demands" + 0.017*"oath_democracy" + 0.017*"history_deserves" + 0.016*"thanks"
# 2022-10-25 17:43:20,469 : INFO : topic #2 (0.250): 0.071*"violence" + 0.046*"thcomm" + 0.045*"love" + 0.045*"maga_gop" + 0.044*"correct" + 0.044*"overthrowing_democracy" + 0.044*"mark_hamill" + 0.044*"country_without_creating" + 0.033*"trump" + 0.022*"says"
# 2022-10-25 17:43:20,471 : INFO : topic #3 (0.250): 0.082*"called" + 0.082*"responsible" + 0.082*"kevin_mccarthy" + 0.082*"mitch_mcconnell" + 0.082*"knew_trump" + 0.082*"backed" + 0.028*"decided" + 0.018*"roger_stone" + 0.017*"trump_lost" + 0.016*"help"
# 2022-10-25 17:43:20,471 : INFO : topic diff=0.215987, rho=0.226476
# 2022-10-25 17:43:20,472 : INFO : PROGRESS: pass 1, at document #14000/34993
# 2022-10-25 17:43:20,716 : INFO : merging changes from 2000 documents into a model of 34993 documents
# 2022-10-25 17:43:20,720 : INFO : topic #0 (0.250): 0.043*"knew" + 0.021*"trump" + 0.009*"violent_armed" + 0.009*"donald_trump" + 0.009*"act" + 0.008*"happened" + 0.008*"plans" + 0.008*"ins" + 0.008*"reason_law" + 0.008*"warnings"
# 2022-10-25 17:43:20,721 : INFO : topic #1 (0.250): 0.049*"trump" + 0.021*"th" + 0.019*"testify" + 0.019*"want" + 0.018*"subpoena_donald" + 0.018*"voted_unanimously" + 0.017*"demands" + 0.017*"oath_democracy" + 0.017*"history_deserves" + 0.013*"thanks"
# 2022-10-25 17:43:20,722 : INFO : topic #2 (0.250): 0.067*"violence" + 0.042*"thcomm" + 0.042*"love" + 0.041*"maga_gop" + 0.040*"correct" + 0.040*"overthrowing_democracy" + 0.040*"mark_hamill" + 0.040*"country_without_creating" + 0.036*"trump" + 0.023*"says"
# 2022-10-25 17:43:20,724 : INFO : topic #3 (0.250): 0.082*"called" + 0.081*"kevin_mccarthy" + 0.081*"responsible" + 0.081*"mitch_mcconnell" + 0.081*"knew_trump" + 0.081*"backed" + 0.029*"decided" + 0.019*"roger_stone" + 0.018*"trump_lost" + 0.018*"help"
# 2022-10-25 17:43:20,724 : INFO : topic diff=0.209997, rho=0.226476
# 2022-10-25 17:43:20,726 : INFO : PROGRESS: pass 1, at document #16000/34993
# 2022-10-25 17:43:20,957 : INFO : merging changes from 2000 documents into a model of 34993 documents
# 2022-10-25 17:43:20,961 : INFO : topic #0 (0.250): 0.046*"knew" + 0.025*"trump" + 0.009*"election" + 0.009*"donald_trump" + 0.009*"happened" + 0.008*"violent_armed" + 0.008*"testified" + 0.008*"act" + 0.008*"held" + 0.008*"democracy"
# 2022-10-25 17:43:20,963 : INFO : topic #1 (0.250): 0.047*"trump" + 0.020*"th" + 0.019*"testify" + 0.018*"subpoena_donald" + 0.018*"voted_unanimously" + 0.017*"demands" + 0.017*"history_deserves" + 0.017*"oath_democracy" + 0.016*"want" + 0.010*"thanks"
# 2022-10-25 17:43:20,964 : INFO : topic #2 (0.250): 0.067*"violence" + 0.042*"thcomm" + 0.042*"love" + 0.041*"maga_gop" + 0.040*"correct" + 0.040*"overthrowing_democracy" + 0.040*"mark_hamill" + 0.040*"country_without_creating" + 0.037*"trump" + 0.023*"says"
# 2022-10-25 17:43:20,965 : INFO : topic #3 (0.250): 0.087*"called" + 0.086*"responsible" + 0.086*"kevin_mccarthy" + 0.086*"knew_trump" + 0.086*"mitch_mcconnell" + 0.086*"backed" + 0.028*"decided" + 0.018*"roger_stone" + 0.018*"trump_lost" + 0.017*"help"
# 2022-10-25 17:43:20,965 : INFO : topic diff=0.202269, rho=0.226476
# 2022-10-25 17:43:20,966 : INFO : PROGRESS: pass 1, at document #18000/34993
# 2022-10-25 17:43:21,206 : INFO : merging changes from 2000 documents into a model of 34993 documents
# 2022-10-25 17:43:21,210 : INFO : topic #0 (0.250): 0.049*"knew" + 0.026*"trump" + 0.010*"election" + 0.009*"donald_trump" + 0.009*"happened" + 0.008*"lost" + 0.008*"testified" + 0.008*"held" + 0.008*"violent_armed" + 0.007*"afraid"
# 2022-10-25 17:43:21,211 : INFO : topic #1 (0.250): 0.050*"trump" + 0.021*"testify" + 0.021*"subpoena_donald" + 0.020*"voted_unanimously" + 0.020*"demands" + 0.020*"history_deserves" + 0.020*"oath_democracy" + 0.016*"th" + 0.013*"want" + 0.009*"going"
# 2022-10-25 17:43:21,212 : INFO : topic #2 (0.250): 0.065*"violence" + 0.040*"thcomm" + 0.040*"love" + 0.039*"maga_gop" + 0.038*"correct" + 0.038*"overthrowing_democracy" + 0.038*"mark_hamill" + 0.038*"country_without_creating" + 0.037*"trump" + 0.022*"says"
# 2022-10-25 17:43:21,213 : INFO : topic #3 (0.250): 0.086*"called" + 0.084*"responsible" + 0.084*"mitch_mcconnell" + 0.084*"kevin_mccarthy" + 0.084*"knew_trump" + 0.084*"backed" + 0.029*"decided" + 0.019*"roger_stone" + 0.018*"trump_lost" + 0.018*"help"
# 2022-10-25 17:43:21,214 : INFO : topic diff=0.227804, rho=0.226476
# 2022-10-25 17:43:21,616 : INFO : -6.465 per-word bound, 88.3 perplexity estimate based on a held-out corpus of 2000 documents with 14458 words
# 2022-10-25 17:43:21,616 : INFO : PROGRESS: pass 1, at document #20000/34993
# 2022-10-25 17:43:21,849 : INFO : merging changes from 2000 documents into a model of 34993 documents
# 2022-10-25 17:43:21,854 : INFO : topic #0 (0.250): 0.049*"knew" + 0.027*"trump" + 0.010*"election" + 0.009*"donald_trump" + 0.009*"happened" + 0.009*"lost" + 0.008*"violent_armed" + 0.008*"testified" + 0.007*"hours" + 0.007*"afraid"
# 2022-10-25 17:43:21,855 : INFO : topic #1 (0.250): 0.051*"trump" + 0.021*"subpoena_donald" + 0.021*"testify" + 0.021*"voted_unanimously" + 0.020*"demands" + 0.020*"history_deserves" + 0.020*"oath_democracy" + 0.015*"th" + 0.012*"want" + 0.009*"going"
# 2022-10-25 17:43:21,856 : INFO : topic #2 (0.250): 0.064*"violence" + 0.038*"thcomm" + 0.037*"love" + 0.037*"trump" + 0.037*"maga_gop" + 0.036*"correct" + 0.036*"overthrowing_democracy" + 0.036*"mark_hamill" + 0.036*"country_without_creating" + 0.021*"says"
# 2022-10-25 17:43:21,857 : INFO : topic #3 (0.250): 0.083*"called" + 0.081*"responsible" + 0.081*"mitch_mcconnell" + 0.081*"kevin_mccarthy" + 0.081*"knew_trump" + 0.081*"backed" + 0.031*"decided" + 0.019*"roger_stone" + 0.019*"trump_lost" + 0.018*"help"
# 2022-10-25 17:43:21,858 : INFO : topic diff=0.231849, rho=0.226476
# 2022-10-25 17:43:21,859 : INFO : PROGRESS: pass 1, at document #22000/34993
# 2022-10-25 17:43:22,087 : INFO : merging changes from 2000 documents into a model of 34993 documents
# 2022-10-25 17:43:22,091 : INFO : topic #0 (0.250): 0.047*"knew" + 0.026*"trump" + 0.011*"happened" + 0.010*"violent_armed" + 0.009*"testified" + 0.009*"donald_trump" + 0.009*"election" + 0.009*"act" + 0.009*"hours" + 0.009*"afraid"
# 2022-10-25 17:43:22,092 : INFO : topic #1 (0.250): 0.052*"trump" + 0.023*"subpoena_donald" + 0.022*"testify" + 0.022*"voted_unanimously" + 0.021*"demands" + 0.021*"oath_democracy" + 0.021*"history_deserves" + 0.014*"th" + 0.010*"going" + 0.010*"want"
# 2022-10-25 17:43:22,093 : INFO : topic #2 (0.250): 0.062*"violence" + 0.040*"trump" + 0.035*"thcomm" + 0.034*"love" + 0.033*"maga_gop" + 0.033*"correct" + 0.033*"overthrowing_democracy" + 0.033*"mark_hamill" + 0.033*"country_without_creating" + 0.022*"th_attack"
# 2022-10-25 17:43:22,094 : INFO : topic #3 (0.250): 0.079*"called" + 0.078*"responsible" + 0.078*"mitch_mcconnell" + 0.078*"knew_trump" + 0.078*"kevin_mccarthy" + 0.078*"backed" + 0.034*"decided" + 0.022*"roger_stone" + 0.021*"trump_lost" + 0.020*"help"
# 2022-10-25 17:43:22,095 : INFO : topic diff=0.214259, rho=0.226476
# 2022-10-25 17:43:22,096 : INFO : PROGRESS: pass 1, at document #24000/34993
# 2022-10-25 17:43:22,326 : INFO : merging changes from 2000 documents into a model of 34993 documents
# 2022-10-25 17:43:22,330 : INFO : topic #0 (0.250): 0.051*"knew" + 0.026*"trump" + 0.011*"happened" + 0.011*"donald_trump" + 0.010*"violent_armed" + 0.010*"testified" + 0.009*"hours" + 0.009*"afraid" + 0.009*"ev" + 0.009*"trump_get"
# 2022-10-25 17:43:22,331 : INFO : topic #1 (0.250): 0.053*"trump" + 0.023*"subpoena_donald" + 0.023*"testify" + 0.022*"voted_unanimously" + 0.021*"demands" + 0.021*"oath_democracy" + 0.021*"history_deserves" + 0.012*"th" + 0.010*"going" + 0.009*"want"
# 2022-10-25 17:43:22,333 : INFO : topic #2 (0.250): 0.060*"violence" + 0.038*"trump" + 0.032*"thcomm" + 0.032*"love" + 0.031*"maga_gop" + 0.030*"correct" + 0.030*"overthrowing_democracy" + 0.030*"mark_hamill" + 0.030*"country_without_creating" + 0.022*"th_attack"
# 2022-10-25 17:43:22,334 : INFO : topic #3 (0.250): 0.077*"called" + 0.077*"responsible" + 0.077*"knew_trump" + 0.076*"kevin_mccarthy" + 0.076*"mitch_mcconnell" + 0.076*"backed" + 0.034*"decided" + 0.022*"roger_stone" + 0.021*"trump_lost" + 0.021*"help"
# 2022-10-25 17:43:22,337 : INFO : topic diff=0.204425, rho=0.226476
# 2022-10-25 17:43:22,338 : INFO : PROGRESS: pass 1, at document #26000/34993
# 2022-10-25 17:43:22,592 : INFO : merging changes from 2000 documents into a model of 34993 documents
# 2022-10-25 17:43:22,597 : INFO : topic #0 (0.250): 0.049*"knew" + 0.025*"trump" + 0.013*"violent_armed" + 0.012*"happened" + 0.011*"testified" + 0.011*"act" + 0.011*"plans" + 0.011*"ins" + 0.011*"reason_law" + 0.011*"warnings"
# 2022-10-25 17:43:22,598 : INFO : topic #1 (0.250): 0.054*"trump" + 0.026*"subpoena_donald" + 0.025*"testify" + 0.024*"voted_unanimously" + 0.024*"demands" + 0.024*"history_deserves" + 0.024*"oath_democracy" + 0.012*"th" + 0.011*"going" + 0.008*"want"
# 2022-10-25 17:43:22,599 : INFO : topic #2 (0.250): 0.055*"violence" + 0.037*"trump" + 0.028*"thcomm" + 0.027*"love" + 0.027*"maga_gop" + 0.026*"correct" + 0.026*"overthrowing_democracy" + 0.026*"mark_hamill" + 0.026*"country_without_creating" + 0.022*"th_attack"
# 2022-10-25 17:43:22,600 : INFO : topic #3 (0.250): 0.074*"called" + 0.073*"knew_trump" + 0.073*"responsible" + 0.073*"mitch_mcconnell" + 0.073*"kevin_mccarthy" + 0.073*"backed" + 0.035*"decided" + 0.025*"roger_stone" + 0.023*"trump_lost" + 0.023*"help"
# 2022-10-25 17:43:22,601 : INFO : topic diff=0.201712, rho=0.226476
# 2022-10-25 17:43:22,601 : INFO : PROGRESS: pass 1, at document #28000/34993
# 2022-10-25 17:43:22,838 : INFO : merging changes from 2000 documents into a model of 34993 documents
# 2022-10-25 17:43:22,842 : INFO : topic #0 (0.250): 0.049*"knew" + 0.024*"trump" + 0.014*"violent_armed" + 0.014*"happened" + 0.012*"act" + 0.012*"testified" + 0.012*"plans" + 0.012*"ins" + 0.012*"reason_law" + 0.012*"warnings"
# 2022-10-25 17:43:22,843 : INFO : topic #1 (0.250): 0.050*"trump" + 0.024*"subpoena_donald" + 0.023*"testify" + 0.022*"voted_unanimously" + 0.022*"demands" + 0.022*"history_deserves" + 0.022*"oath_democracy" + 0.011*"th" + 0.009*"going" + 0.007*"want"
# 2022-10-25 17:43:22,844 : INFO : topic #2 (0.250): 0.054*"violence" + 0.037*"trump" + 0.026*"thcomm" + 0.026*"love" + 0.025*"maga_gop" + 0.025*"correct" + 0.025*"overthrowing_democracy" + 0.025*"mark_hamill" + 0.025*"country_without_creating" + 0.023*"th_attack"
# 2022-10-25 17:43:22,846 : INFO : topic #3 (0.250): 0.073*"called" + 0.072*"knew_trump" + 0.072*"responsible" + 0.072*"mitch_mcconnell" + 0.072*"kevin_mccarthy" + 0.072*"backed" + 0.035*"decided" + 0.026*"roger_stone" + 0.024*"trump_lost" + 0.024*"help"
# 2022-10-25 17:43:22,848 : INFO : topic diff=0.236844, rho=0.226476
# 2022-10-25 17:43:22,850 : INFO : PROGRESS: pass 1, at document #30000/34993
# 2022-10-25 17:43:23,114 : INFO : merging changes from 2000 documents into a model of 34993 documents
# 2022-10-25 17:43:23,119 : INFO : topic #0 (0.250): 0.044*"knew" + 0.023*"trump" + 0.014*"happened" + 0.014*"violent_armed" + 0.012*"testified" + 0.012*"act" + 0.012*"plans" + 0.012*"ins" + 0.012*"reason_law" + 0.012*"warnings"
# 2022-10-25 17:43:23,120 : INFO : topic #1 (0.250): 0.052*"trump" + 0.024*"testify" + 0.024*"subpoena_donald" + 0.023*"voted_unanimously" + 0.023*"demands" + 0.022*"history_deserves" + 0.022*"oath_democracy" + 0.010*"going" + 0.009*"th" + 0.007*"want"
# 2022-10-25 17:43:23,121 : INFO : topic #2 (0.250): 0.056*"violence" + 0.039*"trump" + 0.027*"thcomm" + 0.026*"love" + 0.026*"maga_gop" + 0.025*"th_attack" + 0.025*"trump_summoned" + 0.025*"author" + 0.025*"goaded" + 0.025*"rioters_trump"
# 2022-10-25 17:43:23,122 : INFO : topic #3 (0.250): 0.071*"called" + 0.070*"knew_trump" + 0.070*"responsible" + 0.070*"mitch_mcconnell" + 0.070*"kevin_mccarthy" + 0.070*"backed" + 0.034*"decided" + 0.026*"roger_stone" + 0.025*"trump_lost" + 0.024*"help"
# 2022-10-25 17:43:23,123 : INFO : topic diff=0.208833, rho=0.226476
# 2022-10-25 17:43:23,124 : INFO : PROGRESS: pass 1, at document #32000/34993
# 2022-10-25 17:43:23,379 : INFO : merging changes from 2000 documents into a model of 34993 documents
# 2022-10-25 17:43:23,384 : INFO : topic #0 (0.250): 0.048*"knew" + 0.022*"trump" + 0.016*"happened" + 0.014*"testified" + 0.014*"afraid" + 0.014*"violent_armed" + 0.014*"hours" + 0.014*"ev" + 0.014*"trump_get" + 0.013*"biggest_audience"
# 2022-10-25 17:43:23,385 : INFO : topic #1 (0.250): 0.055*"trump" + 0.025*"testify" + 0.025*"subpoena_donald" + 0.024*"voted_unanimously" + 0.023*"demands" + 0.023*"history_deserves" + 0.023*"oath_democracy" + 0.010*"going" + 0.009*"th" + 0.007*"want"
# 2022-10-25 17:43:23,386 : INFO : topic #2 (0.250): 0.057*"violence" + 0.041*"trump" + 0.027*"trump_summoned" + 0.027*"th_attack" + 0.026*"author" + 0.026*"goaded" + 0.026*"rioters_trump" + 0.026*"trump_excuse" + 0.026*"thcomm" + 0.025*"love"
# 2022-10-25 17:43:23,387 : INFO : topic #3 (0.250): 0.073*"called" + 0.073*"responsible" + 0.073*"knew_trump" + 0.072*"mitch_mcconnell" + 0.072*"kevin_mccarthy" + 0.072*"backed" + 0.031*"decided" + 0.024*"roger_stone" + 0.023*"trump_lost" + 0.022*"help"
# 2022-10-25 17:43:23,388 : INFO : topic diff=0.183877, rho=0.226476
# 2022-10-25 17:43:23,389 : INFO : PROGRESS: pass 1, at document #34000/34993
# 2022-10-25 17:43:23,644 : INFO : merging changes from 2000 documents into a model of 34993 documents
# 2022-10-25 17:43:23,649 : INFO : topic #0 (0.250): 0.050*"knew" + 0.021*"trump" + 0.016*"happened" + 0.015*"testified" + 0.014*"afraid" + 0.014*"hours" + 0.014*"ev" + 0.014*"trump_get" + 0.014*"hey_trump" + 0.014*"oath_come"
# 2022-10-25 17:43:23,651 : INFO : topic #1 (0.250): 0.056*"trump" + 0.027*"subpoena_donald" + 0.027*"testify" + 0.026*"voted_unanimously" + 0.025*"demands" + 0.025*"oath_democracy" + 0.025*"history_deserves" + 0.010*"going" + 0.008*"th" + 0.007*"want"
# 2022-10-25 17:43:23,652 : INFO : topic #2 (0.250): 0.055*"violence" + 0.042*"trump" + 0.027*"trump_summoned" + 0.027*"th_attack" + 0.027*"author" + 0.027*"goaded" + 0.027*"rioters_trump" + 0.027*"trump_excuse" + 0.024*"thcomm" + 0.023*"love"
# 2022-10-25 17:43:23,652 : INFO : topic #3 (0.250): 0.074*"mitch_mcconnell" + 0.074*"called" + 0.074*"responsible" + 0.074*"knew_trump" + 0.074*"kevin_mccarthy" + 0.074*"backed" + 0.029*"decided" + 0.023*"roger_stone" + 0.022*"trump_lost" + 0.021*"help"
# 2022-10-25 17:43:23,653 : INFO : topic diff=0.168897, rho=0.226476
# 2022-10-25 17:43:23,875 : INFO : -6.180 per-word bound, 72.5 perplexity estimate based on a held-out corpus of 993 documents with 6779 words
# 2022-10-25 17:43:23,876 : INFO : PROGRESS: pass 1, at document #34993/34993
# 2022-10-25 17:43:24,010 : INFO : merging changes from 993 documents into a model of 34993 documents
# 2022-10-25 17:43:24,014 : INFO : topic #0 (0.250): 0.044*"knew" + 0.019*"trump" + 0.016*"happened" + 0.015*"testified" + 0.014*"hours" + 0.014*"afraid" + 0.014*"ev" + 0.014*"trump_get" + 0.014*"hey_trump" + 0.014*"biggest_audience"
# 2022-10-25 17:43:24,015 : INFO : topic #1 (0.250): 0.057*"trump" + 0.028*"subpoena_donald" + 0.028*"testify" + 0.027*"voted_unanimously" + 0.026*"demands" + 0.026*"oath_democracy" + 0.026*"history_deserves" + 0.009*"going" + 0.007*"th" + 0.006*"watch"
# 2022-10-25 17:43:24,016 : INFO : topic #2 (0.250): 0.056*"violence" + 0.045*"trump" + 0.029*"trump_summoned" + 0.029*"th_attack" + 0.028*"author" + 0.028*"goaded" + 0.028*"rioters_trump" + 0.028*"trump_excuse" + 0.024*"shit" + 0.023*"thcomm"
# 2022-10-25 17:43:24,017 : INFO : topic #3 (0.250): 0.074*"called" + 0.074*"mitch_mcconnell" + 0.074*"knew_trump" + 0.074*"responsible" + 0.074*"kevin_mccarthy" + 0.074*"backed" + 0.027*"decided" + 0.021*"roger_stone" + 0.021*"trump_lost" + 0.020*"thing"
# 2022-10-25 17:43:24,018 : INFO : topic diff=0.161001, rho=0.226476
# 2022-10-25 17:43:24,019 : INFO : PROGRESS: pass 2, at document #2000/34993
# 2022-10-25 17:43:24,286 : INFO : merging changes from 2000 documents into a model of 34993 documents
# 2022-10-25 17:43:24,290 : INFO : topic #0 (0.250): 0.046*"knew" + 0.018*"trump" + 0.014*"happened" + 0.013*"testified" + 0.012*"afraid" + 0.012*"hours" + 0.012*"ev" + 0.012*"trump_get" + 0.012*"oath_come" + 0.012*"hey_trump"
# 2022-10-25 17:43:24,291 : INFO : topic #1 (0.250): 0.053*"trump" + 0.024*"testify" + 0.024*"subpoena_donald" + 0.023*"voted_unanimously" + 0.022*"demands" + 0.022*"history_deserves" + 0.022*"oath_democracy" + 0.012*"th" + 0.010*"going" + 0.009*"want"
# 2022-10-25 17:43:24,292 : INFO : topic #2 (0.250): 0.058*"violence" + 0.039*"trump" + 0.030*"thcomm" + 0.029*"love" + 0.028*"maga_gop" + 0.028*"correct" + 0.028*"country_without_creating" + 0.028*"overthrowing_democracy" + 0.028*"mark_hamill" + 0.025*"trump_summoned"
# 2022-10-25 17:43:24,294 : INFO : topic #3 (0.250): 0.076*"called" + 0.076*"responsible" + 0.076*"mitch_mcconnell" + 0.076*"knew_trump" + 0.076*"kevin_mccarthy" + 0.076*"backed" + 0.028*"decided" + 0.021*"roger_stone" + 0.020*"trump_lost" + 0.019*"help"
# 2022-10-25 17:43:24,297 : INFO : topic diff=0.245414, rho=0.220882
# 2022-10-25 17:43:24,298 : INFO : PROGRESS: pass 2, at document #4000/34993
# 2022-10-25 17:43:24,568 : INFO : merging changes from 2000 documents into a model of 34993 documents
# 2022-10-25 17:43:24,573 : INFO : topic #0 (0.250): 0.048*"knew" + 0.016*"trump" + 0.015*"nancy_pelosi" + 0.012*"happened" + 0.011*"would" + 0.011*"testified" + 0.011*"th" + 0.010*"afraid" + 0.010*"hours" + 0.010*"ev"
# 2022-10-25 17:43:24,574 : INFO : topic #1 (0.250): 0.049*"trump" + 0.022*"testify" + 0.021*"subpoena_donald" + 0.020*"voted_unanimously" + 0.020*"demands" + 0.020*"oath_democracy" + 0.020*"history_deserves" + 0.016*"th" + 0.013*"want" + 0.010*"going"
# 2022-10-25 17:43:24,575 : INFO : topic #2 (0.250): 0.062*"violence" + 0.035*"trump" + 0.035*"thcomm" + 0.034*"love" + 0.034*"maga_gop" + 0.033*"correct" + 0.033*"country_without_creating" + 0.033*"mark_hamill" + 0.033*"overthrowing_democracy" + 0.023*"trump_summoned"
# 2022-10-25 17:43:24,576 : INFO : topic #3 (0.250): 0.078*"called" + 0.078*"responsible" + 0.078*"mitch_mcconnell" + 0.078*"knew_trump" + 0.078*"kevin_mccarthy" + 0.078*"backed" + 0.028*"decided" + 0.020*"roger_stone" + 0.018*"trump_lost" + 0.018*"help"
# 2022-10-25 17:43:24,576 : INFO : topic diff=0.224367, rho=0.220882
# 2022-10-25 17:43:24,578 : INFO : PROGRESS: pass 2, at document #6000/34993
# ...
# 2022-10-25 17:44:00,324 : INFO : topic #3 (0.250): 0.083*"called" + 0.083*"responsible" + 0.083*"kevin_mccarthy" + 0.083*"mitch_mcconnell" + 0.083*"knew_trump" + 0.082*"backed" + 0.029*"decided" + 0.019*"roger_stone" + 0.018*"trump_lost" + 0.017*"help"
# 2022-10-25 17:44:00,325 : INFO : topic diff=0.153946, rho=0.190705
# 2022-10-25 17:44:00,326 : INFO : PROGRESS: pass 9, at document #14000/34993
# 2022-10-25 17:44:00,544 : INFO : merging changes from 2000 documents into a model of 34993 documents
# 2022-10-25 17:44:00,548 : INFO : topic #0 (0.250): 0.043*"knew" + 0.020*"trump" + 0.009*"nancy_pelosi" + 0.009*"violent_armed" + 0.009*"happened" + 0.009*"donald_trump" + 0.009*"act" + 0.008*"plans" + 0.008*"testified" + 0.008*"ins"
# 2022-10-25 17:44:00,549 : INFO : topic #1 (0.250): 0.047*"trump" + 0.019*"th" + 0.018*"testify" + 0.017*"subpoena_donald" + 0.017*"voted_unanimously" + 0.017*"want" + 0.016*"demands" + 0.016*"history_deserves" + 0.016*"oath_democracy" + 0.012*"thanks"
# 2022-10-25 17:44:00,551 : INFO : topic #2 (0.250): 0.069*"violence" + 0.043*"thcomm" + 0.042*"love" + 0.042*"maga_gop" + 0.041*"correct" + 0.041*"mark_hamill" + 0.041*"overthrowing_democracy" + 0.041*"country_without_creating" + 0.036*"trump" + 0.023*"says"
# 2022-10-25 17:44:00,552 : INFO : topic #3 (0.250): 0.082*"called" + 0.082*"responsible" + 0.082*"kevin_mccarthy" + 0.082*"mitch_mcconnell" + 0.082*"knew_trump" + 0.082*"backed" + 0.029*"decided" + 0.020*"roger_stone" + 0.019*"trump_lost" + 0.018*"help"
# 2022-10-25 17:44:00,552 : INFO : topic diff=0.147512, rho=0.190705
# 2022-10-25 17:44:00,553 : INFO : PROGRESS: pass 9, at document #16000/34993
# 2022-10-25 17:44:00,769 : INFO : merging changes from 2000 documents into a model of 34993 documents
# 2022-10-25 17:44:00,773 : INFO : topic #0 (0.250): 0.047*"knew" + 0.023*"trump" + 0.009*"donald_trump" + 0.009*"happened" + 0.009*"election" + 0.008*"nancy_pelosi" + 0.008*"violent_armed" + 0.008*"testified" + 0.008*"act" + 0.008*"democracy"
# 2022-10-25 17:44:00,775 : INFO : topic #1 (0.250): 0.046*"trump" + 0.018*"th" + 0.018*"testify" + 0.017*"subpoena_donald" + 0.017*"voted_unanimously" + 0.016*"demands" + 0.016*"history_deserves" + 0.016*"oath_democracy" + 0.015*"want" + 0.010*"thanks"
# 2022-10-25 17:44:00,776 : INFO : topic #2 (0.250): 0.069*"violence" + 0.043*"thcomm" + 0.042*"love" + 0.041*"maga_gop" + 0.041*"correct" + 0.041*"mark_hamill" + 0.041*"overthrowing_democracy" + 0.041*"country_without_creating" + 0.037*"trump" + 0.023*"says"
# 2022-10-25 17:44:00,777 : INFO : topic #3 (0.250): 0.087*"called" + 0.086*"responsible" + 0.086*"kevin_mccarthy" + 0.086*"knew_trump" + 0.086*"mitch_mcconnell" + 0.086*"backed" + 0.028*"decided" + 0.020*"roger_stone" + 0.018*"trump_lost" + 0.017*"help"
# 2022-10-25 17:44:00,778 : INFO : topic diff=0.144852, rho=0.190705
# 2022-10-25 17:44:00,779 : INFO : PROGRESS: pass 9, at document #18000/34993
# 2022-10-25 17:44:01,000 : INFO : merging changes from 2000 documents into a model of 34993 documents
# 2022-10-25 17:44:01,005 : INFO : topic #0 (0.250): 0.049*"knew" + 0.025*"trump" + 0.010*"election" + 0.009*"donald_trump" + 0.009*"happened" + 0.008*"testified" + 0.008*"lost" + 0.008*"violent_armed" + 0.008*"afraid" + 0.008*"hours"
# 2022-10-25 17:44:01,006 : INFO : topic #1 (0.250): 0.047*"trump" + 0.019*"testify" + 0.019*"subpoena_donald" + 0.018*"voted_unanimously" + 0.018*"demands" + 0.018*"oath_democracy" + 0.018*"history_deserves" + 0.015*"th" + 0.013*"want" + 0.010*"going"
# 2022-10-25 17:44:01,007 : INFO : topic #2 (0.250): 0.067*"violence" + 0.041*"thcomm" + 0.041*"love" + 0.040*"maga_gop" + 0.039*"correct" + 0.039*"mark_hamill" + 0.039*"overthrowing_democracy" + 0.039*"country_without_creating" + 0.037*"trump" + 0.022*"says"
# 2022-10-25 17:44:01,008 : INFO : topic #3 (0.250): 0.086*"called" + 0.085*"responsible" + 0.085*"mitch_mcconnell" + 0.085*"kevin_mccarthy" + 0.085*"knew_trump" + 0.084*"backed" + 0.029*"decided" + 0.020*"roger_stone" + 0.019*"trump_lost" + 0.018*"help"
# 2022-10-25 17:44:01,009 : INFO : topic diff=0.167251, rho=0.190705
# 2022-10-25 17:44:01,391 : INFO : -6.408 per-word bound, 84.9 perplexity estimate based on a held-out corpus of 2000 documents with 14458 words
# 2022-10-25 17:44:01,392 : INFO : PROGRESS: pass 9, at document #20000/34993
# 2022-10-25 17:44:01,615 : INFO : merging changes from 2000 documents into a model of 34993 documents
# 2022-10-25 17:44:01,619 : INFO : topic #0 (0.250): 0.050*"knew" + 0.026*"trump" + 0.009*"election" + 0.009*"donald_trump" + 0.009*"happened" + 0.008*"lost" + 0.008*"testified" + 0.008*"violent_armed" + 0.008*"hours" + 0.008*"afraid"
# 2022-10-25 17:44:01,620 : INFO : topic #1 (0.250): 0.049*"trump" + 0.020*"subpoena_donald" + 0.020*"testify" + 0.019*"voted_unanimously" + 0.018*"demands" + 0.018*"oath_democracy" + 0.018*"history_deserves" + 0.014*"th" + 0.011*"want" + 0.010*"going"
# 2022-10-25 17:44:01,621 : INFO : topic #2 (0.250): 0.066*"violence" + 0.039*"thcomm" + 0.039*"love" + 0.038*"maga_gop" + 0.037*"correct" + 0.037*"trump" + 0.037*"overthrowing_democracy" + 0.037*"mark_hamill" + 0.037*"country_without_creating" + 0.022*"says"
# 2022-10-25 17:44:01,622 : INFO : topic #3 (0.250): 0.083*"called" + 0.082*"responsible" + 0.082*"mitch_mcconnell" + 0.082*"kevin_mccarthy" + 0.082*"knew_trump" + 0.082*"backed" + 0.031*"decided" + 0.021*"roger_stone" + 0.019*"trump_lost" + 0.018*"help"
# 2022-10-25 17:44:01,623 : INFO : topic diff=0.171304, rho=0.190705
# 2022-10-25 17:44:01,624 : INFO : PROGRESS: pass 9, at document #22000/34993
# 2022-10-25 17:44:01,840 : INFO : merging changes from 2000 documents into a model of 34993 documents
# 2022-10-25 17:44:01,844 : INFO : topic #0 (0.250): 0.048*"knew" + 0.025*"trump" + 0.011*"happened" + 0.010*"violent_armed" + 0.009*"testified" + 0.009*"donald_trump" + 0.009*"election" + 0.009*"act" + 0.009*"hours" + 0.009*"afraid"
# 2022-10-25 17:44:01,845 : INFO : topic #1 (0.250): 0.050*"trump" + 0.021*"subpoena_donald" + 0.020*"testify" + 0.020*"voted_unanimously" + 0.019*"demands" + 0.019*"history_deserves" + 0.019*"oath_democracy" + 0.013*"th" + 0.011*"going" + 0.010*"want"
# 2022-10-25 17:44:01,846 : INFO : topic #2 (0.250): 0.065*"violence" + 0.040*"trump" + 0.037*"thcomm" + 0.036*"love" + 0.035*"maga_gop" + 0.035*"correct" + 0.035*"mark_hamill" + 0.035*"overthrowing_democracy" + 0.035*"country_without_creating" + 0.023*"th_attack"
# 2022-10-25 17:44:01,847 : INFO : topic #3 (0.250): 0.080*"called" + 0.079*"responsible" + 0.079*"mitch_mcconnell" + 0.079*"knew_trump" + 0.079*"kevin_mccarthy" + 0.079*"backed" + 0.033*"decided" + 0.023*"roger_stone" + 0.021*"trump_lost" + 0.020*"help"
# 2022-10-25 17:44:01,847 : INFO : topic diff=0.158182, rho=0.190705
# 2022-10-25 17:44:01,849 : INFO : PROGRESS: pass 9, at document #24000/34993
# 2022-10-25 17:44:02,064 : INFO : merging changes from 2000 documents into a model of 34993 documents
# 2022-10-25 17:44:02,068 : INFO : topic #0 (0.250): 0.051*"knew" + 0.025*"trump" + 0.011*"happened" + 0.011*"donald_trump" + 0.010*"violent_armed" + 0.010*"testified" + 0.009*"hours" + 0.009*"afraid" + 0.009*"ev" + 0.009*"trump_get"
# 2022-10-25 17:44:02,069 : INFO : topic #1 (0.250): 0.051*"trump" + 0.021*"subpoena_donald" + 0.021*"testify" + 0.020*"voted_unanimously" + 0.019*"demands" + 0.019*"oath_democracy" + 0.019*"history_deserves" + 0.012*"th" + 0.011*"going" + 0.009*"want"
# 2022-10-25 17:44:02,070 : INFO : topic #2 (0.250): 0.062*"violence" + 0.038*"trump" + 0.034*"thcomm" + 0.034*"love" + 0.033*"maga_gop" + 0.032*"correct" + 0.032*"overthrowing_democracy" + 0.032*"country_without_creating" + 0.032*"mark_hamill" + 0.022*"th_attack"
# 2022-10-25 17:44:02,071 : INFO : topic #3 (0.250): 0.079*"called" + 0.078*"responsible" + 0.078*"knew_trump" + 0.078*"mitch_mcconnell" + 0.078*"kevin_mccarthy" + 0.077*"backed" + 0.033*"decided" + 0.023*"roger_stone" + 0.021*"trump_lost" + 0.021*"help"
# 2022-10-25 17:44:02,072 : INFO : topic diff=0.151392, rho=0.190705
# 2022-10-25 17:44:02,073 : INFO : PROGRESS: pass 9, at document #26000/34993
# 2022-10-25 17:44:02,291 : INFO : merging changes from 2000 documents into a model of 34993 documents
# 2022-10-25 17:44:02,295 : INFO : topic #0 (0.250): 0.050*"knew" + 0.025*"trump" + 0.012*"violent_armed" + 0.012*"happened" + 0.011*"testified" + 0.011*"act" + 0.010*"plans" + 0.010*"ins" + 0.010*"reason_law" + 0.010*"enforcement_failed"
# 2022-10-25 17:44:02,296 : INFO : topic #1 (0.250): 0.051*"trump" + 0.023*"subpoena_donald" + 0.023*"testify" + 0.022*"voted_unanimously" + 0.021*"demands" + 0.021*"oath_democracy" + 0.021*"history_deserves" + 0.012*"th" + 0.011*"going" + 0.008*"want"
# 2022-10-25 17:44:02,297 : INFO : topic #2 (0.250): 0.058*"violence" + 0.037*"trump" + 0.030*"thcomm" + 0.030*"love" + 0.029*"maga_gop" + 0.028*"correct" + 0.028*"mark_hamill" + 0.028*"overthrowing_democracy" + 0.028*"country_without_creating" + 0.023*"th_attack"
# 2022-10-25 17:44:02,298 : INFO : topic #3 (0.250): 0.075*"called" + 0.075*"knew_trump" + 0.075*"responsible" + 0.075*"mitch_mcconnell" + 0.075*"kevin_mccarthy" + 0.074*"backed" + 0.034*"decided" + 0.025*"roger_stone" + 0.023*"trump_lost" + 0.022*"help"
# 2022-10-25 17:44:02,299 : INFO : topic diff=0.149226, rho=0.190705
# 2022-10-25 17:44:02,300 : INFO : PROGRESS: pass 9, at document #28000/34993
# 2022-10-25 17:44:02,523 : INFO : merging changes from 2000 documents into a model of 34993 documents
# 2022-10-25 17:44:02,528 : INFO : topic #0 (0.250): 0.049*"knew" + 0.024*"trump" + 0.013*"happened" + 0.013*"violent_armed" + 0.012*"act" + 0.012*"testified" + 0.012*"plans" + 0.012*"ins" + 0.012*"reason_law" + 0.012*"flood"
# 2022-10-25 17:44:02,529 : INFO : topic #1 (0.250): 0.049*"trump" + 0.022*"subpoena_donald" + 0.022*"testify" + 0.021*"voted_unanimously" + 0.020*"demands" + 0.020*"history_deserves" + 0.020*"oath_democracy" + 0.011*"th" + 0.010*"going" + 0.007*"want"
# 2022-10-25 17:44:02,530 : INFO : topic #2 (0.250): 0.056*"violence" + 0.038*"trump" + 0.029*"thcomm" + 0.028*"love" + 0.028*"maga_gop" + 0.027*"correct" + 0.027*"mark_hamill" + 0.027*"country_without_creating" + 0.027*"overthrowing_democracy" + 0.023*"th_attack"
# 2022-10-25 17:44:02,531 : INFO : topic #3 (0.250): 0.074*"called" + 0.074*"knew_trump" + 0.074*"responsible" + 0.073*"mitch_mcconnell" + 0.073*"kevin_mccarthy" + 0.073*"backed" + 0.034*"decided" + 0.026*"roger_stone" + 0.024*"trump_lost" + 0.023*"help"
# 2022-10-25 17:44:02,532 : INFO : topic diff=0.180288, rho=0.190705
# 2022-10-25 17:44:02,533 : INFO : PROGRESS: pass 9, at document #30000/34993
# 2022-10-25 17:44:02,754 : INFO : merging changes from 2000 documents into a model of 34993 documents
# 2022-10-25 17:44:02,758 : INFO : topic #0 (0.250): 0.045*"knew" + 0.023*"trump" + 0.014*"happened" + 0.013*"violent_armed" + 0.012*"testified" + 0.012*"act" + 0.012*"plans" + 0.012*"ins" + 0.012*"reason_law" + 0.012*"warnings"
# 2022-10-25 17:44:02,759 : INFO : topic #1 (0.250): 0.050*"trump" + 0.023*"testify" + 0.022*"subpoena_donald" + 0.021*"voted_unanimously" + 0.021*"demands" + 0.021*"oath_democracy" + 0.021*"history_deserves" + 0.010*"going" + 0.010*"th" + 0.007*"want"
# 2022-10-25 17:44:02,761 : INFO : topic #2 (0.250): 0.059*"violence" + 0.039*"trump" + 0.029*"thcomm" + 0.028*"love" + 0.028*"maga_gop" + 0.027*"correct" + 0.027*"overthrowing_democracy" + 0.027*"country_without_creating" + 0.027*"mark_hamill" + 0.025*"th_attack"
# 2022-10-25 17:44:02,761 : INFO : topic #3 (0.250): 0.072*"called" + 0.072*"knew_trump" + 0.072*"responsible" + 0.072*"mitch_mcconnell" + 0.072*"kevin_mccarthy" + 0.072*"backed" + 0.034*"decided" + 0.026*"roger_stone" + 0.024*"trump_lost" + 0.023*"help"
# 2022-10-25 17:44:02,762 : INFO : topic diff=0.159189, rho=0.190705
# 2022-10-25 17:44:02,763 : INFO : PROGRESS: pass 9, at document #32000/34993
# 2022-10-25 17:44:02,979 : INFO : merging changes from 2000 documents into a model of 34993 documents
# 2022-10-25 17:44:02,983 : INFO : topic #0 (0.250): 0.049*"knew" + 0.022*"trump" + 0.016*"happened" + 0.014*"testified" + 0.014*"violent_armed" + 0.013*"afraid" + 0.013*"hours" + 0.013*"ev" + 0.013*"trump_get" + 0.013*"biggest_audience"
# 2022-10-25 17:44:02,985 : INFO : topic #1 (0.250): 0.052*"trump" + 0.023*"testify" + 0.023*"subpoena_donald" + 0.022*"voted_unanimously" + 0.022*"demands" + 0.022*"oath_democracy" + 0.022*"history_deserves" + 0.011*"going" + 0.009*"th" + 0.007*"want"
# 2022-10-25 17:44:02,986 : INFO : topic #2 (0.250): 0.059*"violence" + 0.041*"trump" + 0.028*"thcomm" + 0.027*"love" + 0.027*"maga_gop" + 0.027*"trump_summoned" + 0.027*"th_attack" + 0.027*"author" + 0.027*"goaded" + 0.027*"rioters_trump"
# 2022-10-25 17:44:02,987 : INFO : topic #3 (0.250): 0.074*"called" + 0.074*"responsible" + 0.074*"knew_trump" + 0.073*"mitch_mcconnell" + 0.073*"kevin_mccarthy" + 0.073*"backed" + 0.031*"decided" + 0.024*"roger_stone" + 0.023*"trump_lost" + 0.022*"help"
# 2022-10-25 17:44:02,988 : INFO : topic diff=0.138356, rho=0.190705
# 2022-10-25 17:44:02,989 : INFO : PROGRESS: pass 9, at document #34000/34993
# 2022-10-25 17:44:03,208 : INFO : merging changes from 2000 documents into a model of 34993 documents
# 2022-10-25 17:44:03,212 : INFO : topic #0 (0.250): 0.050*"knew" + 0.021*"trump" + 0.016*"happened" + 0.014*"testified" + 0.014*"afraid" + 0.014*"hours" + 0.014*"ev" + 0.014*"trump_get" + 0.013*"oath_come" + 0.013*"biggest_audience"
# 2022-10-25 17:44:03,214 : INFO : topic #1 (0.250): 0.054*"trump" + 0.025*"subpoena_donald" + 0.025*"testify" + 0.024*"voted_unanimously" + 0.023*"demands" + 0.023*"history_deserves" + 0.023*"oath_democracy" + 0.010*"going" + 0.008*"th" + 0.007*"want"
# 2022-10-25 17:44:03,215 : INFO : topic #2 (0.250): 0.057*"violence" + 0.042*"trump" + 0.027*"trump_summoned" + 0.027*"th_attack" + 0.027*"author" + 0.027*"goaded" + 0.027*"rioters_trump" + 0.027*"trump_excuse" + 0.026*"thcomm" + 0.025*"love"
# 2022-10-25 17:44:03,216 : INFO : topic #3 (0.250): 0.075*"called" + 0.075*"mitch_mcconnell" + 0.075*"responsible" + 0.074*"knew_trump" + 0.074*"kevin_mccarthy" + 0.074*"backed" + 0.030*"decided" + 0.023*"roger_stone" + 0.022*"trump_lost" + 0.021*"help"
# 2022-10-25 17:44:03,216 : INFO : topic diff=0.128791, rho=0.190705
# 2022-10-25 17:44:03,413 : INFO : -6.146 per-word bound, 70.8 perplexity estimate based on a held-out corpus of 993 documents with 6779 words
# 2022-10-25 17:44:03,414 : INFO : PROGRESS: pass 9, at document #34993/34993
# 2022-10-25 17:44:03,527 : INFO : merging changes from 993 documents into a model of 34993 documents
# 2022-10-25 17:44:03,531 : INFO : topic #0 (0.250): 0.045*"knew" + 0.019*"trump" + 0.016*"happened" + 0.014*"testified" + 0.014*"hours" + 0.014*"afraid" + 0.014*"ev" + 0.014*"trump_get" + 0.013*"hey_trump" + 0.013*"biggest_audience"
# 2022-10-25 17:44:03,532 : INFO : topic #1 (0.250): 0.055*"trump" + 0.026*"subpoena_donald" + 0.026*"testify" + 0.025*"voted_unanimously" + 0.025*"demands" + 0.025*"history_deserves" + 0.025*"oath_democracy" + 0.010*"going" + 0.008*"th" + 0.006*"want"
# 2022-10-25 17:44:03,533 : INFO : topic #2 (0.250): 0.058*"violence" + 0.044*"trump" + 0.029*"trump_summoned" + 0.028*"th_attack" + 0.028*"author" + 0.028*"goaded" + 0.028*"rioters_trump" + 0.028*"trump_excuse" + 0.025*"thcomm" + 0.024*"love"
# 2022-10-25 17:44:03,534 : INFO : topic #3 (0.250): 0.075*"called" + 0.075*"mitch_mcconnell" + 0.075*"knew_trump" + 0.075*"responsible" + 0.074*"kevin_mccarthy" + 0.074*"backed" + 0.028*"decided" + 0.022*"roger_stone" + 0.021*"trump_lost" + 0.020*"help"
# 2022-10-25 17:44:03,535 : INFO : topic diff=0.120547, rho=0.190705
# 2022-10-25 17:44:03,536 : INFO : LdaModel lifecycle event {'msg': 'trained LdaModel(num_terms=11177, num_topics=4, decay=0.5, chunksize=2000) in 51.20s', 'datetime': '2022-10-25T17:44:03.536726', 'gensim': '4.1.2', 'python': '3.9.7 (default, Sep 16 2021, 08:50:36) \n[Clang 10.0.0 ]', 'platform': 'macOS-10.16-x86_64-i386-64bit', 'event': 'created'}

# %%
#see the top ten keywords for each topic and the weightage(importance) of each keyword using
#The weights reflect how important a keyword is to that topic.
lda_model.print_topics()
# Out:
# 2022-10-25 17:45:32,331 : INFO : topic #0 (0.250): 0.045*"knew" + 0.019*"trump" + 0.016*"happened" + 0.014*"testified" + 0.014*"hours" + 0.014*"afraid" + 0.014*"ev" + 0.014*"trump_get" + 0.013*"hey_trump" + 0.013*"biggest_audience"
# 2022-10-25 17:45:32,332 : INFO : topic #1 (0.250): 0.055*"trump" + 0.026*"subpoena_donald" + 0.026*"testify" + 0.025*"voted_unanimously" + 0.025*"demands" + 0.025*"history_deserves" + 0.025*"oath_democracy" + 0.010*"going" + 0.008*"th" + 0.006*"want"
# 2022-10-25 17:45:32,334 : INFO : topic #2 (0.250): 0.058*"violence" + 0.044*"trump" + 0.029*"trump_summoned" + 0.028*"th_attack" + 0.028*"author" + 0.028*"goaded" + 0.028*"rioters_trump" + 0.028*"trump_excuse" + 0.025*"thcomm" + 0.024*"love"
# 2022-10-25 17:45:32,335 : INFO : topic #3 (0.250): 0.075*"called" + 0.075*"mitch_mcconnell" + 0.075*"knew_trump" + 0.075*"responsible" + 0.074*"kevin_mccarthy" + 0.074*"backed" + 0.028*"decided" + 0.022*"roger_stone" + 0.021*"trump_lost" + 0.020*"help"
# [(0,
#   '0.045*"knew" + 0.019*"trump" + 0.016*"happened" + 0.014*"testified" + 0.014*"hours" + 0.014*"afraid" + 0.014*"ev" + 0.014*"trump_get" + 0.013*"hey_trump" + 0.013*"biggest_audience"'),
#  (1,
#   '0.055*"trump" + 0.026*"subpoena_donald" + 0.026*"testify" + 0.025*"voted_unanimously" + 0.025*"demands" + 0.025*"history_deserves" + 0.025*"oath_democracy" + 0.010*"going" + 0.008*"th" + 0.006*"want"'),
#  (2,
#   '0.058*"violence" + 0.044*"trump" + 0.029*"trump_summoned" + 0.028*"th_attack" + 0.028*"author" + 0.028*"goaded" + 0.028*"rioters_trump" + 0.028*"trump_excuse" + 0.025*"thcomm" + 0.024*"love"'),
#  (3,
#   '0.075*"called" + 0.075*"mitch_mcconnell" + 0.075*"knew_trump" + 0.075*"responsible" + 0.074*"kevin_mccarthy" + 0.074*"backed" + 0.028*"decided" + 0.022*"roger_stone" + 0.021*"trump_lost" + 0.020*"help"')]

# %%
# # Visualize the topics
# pyLDAvis.enable_notebook()
# vis = pyLDAvis.gensim.prepare(lda_model, corpus2, id2word)
# vis
